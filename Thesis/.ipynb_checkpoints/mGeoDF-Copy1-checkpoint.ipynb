# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] =15,9
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
import geopandas as gp
import pandas as pd
from shapely.geometry import Point
from shapely import wkt
from shapely.geometry import Polygon
import json
from folium.plugins import TimeSliderChoropleth

# %%
df = pd.read_csv('sensity_events.csv')

# %%
df.dropna(axis=0,how='any',inplace=True)
# df.drop(columns='geometry',inplace=True)
df.drop(columns='session_type',inplace=True)

# %%
df.drop(columns='uuid',inplace=True)

# %%
df.drop(columns='latitude',inplace=True)
df.drop(columns='longitude',inplace=True)

# %%
df.rename(columns={'start_time':'start_date','end_time':'end_date'},inplace=True)

# %%
df['start_date'] = pd.to_datetime(df.start_date,format='%Y/%m/%d').astype('datetime64[s]')
df['end_date'] = pd.to_datetime(df.end_date,format='%Y/%m/%d').astype('datetime64[s]')

# %%
df.head()
# Out:
#         asset_id          start_date            end_date  \
# 0  SENSITY-kc-23 2018-08-10 23:33:26 2018-08-10 23:33:55
# 1  SENSITY-kc-22 2018-08-10 23:34:58 2018-08-10 23:36:08
# 2  SENSITY-kc-10 2018-08-10 23:33:40 2018-08-10 23:36:25
# 3  SENSITY-kc-12 2018-08-10 23:34:44 2018-08-10 23:38:53
# 4   SENSITY-kc-9 2018-08-10 23:37:38 2018-08-10 23:39:01
#
#                                             geometry
# 0  {"type":"Polygon","coordinates":[[[-94.5834598...
# 1  {"type":"Polygon","coordinates":[[[-94.5807547...
# 2  {"type":"Polygon","coordinates":[[[-94.5834062...
# 3  {"type":"Polygon","coordinates":[[[-94.5835249...
# 4  {"type":"Polygon","coordinates":[[[-94.5836287...

# %%
dist_df = df[['asset_id','start_date','end_date','geometry']].drop_duplicates()

# %%
df['start_date'] = pd.to_datetime(df.start_date,format='%Y/%m/%d').astype('datetime64[s]')
df['end_date'] = pd.to_datetime(df.end_date,format='%Y/%m/%d').astype('datetime64[s]')

# %%
dist_df['start_from_fc']= dist_df.start_date.dt.floor('5min')
dist_df['end_from_fc'] = dist_df.end_date.dt.ceil('5min')

# %%
n = (dist_df.end_from_fc - dist_df.start_from_fc)
# n,(n.dt.total_seconds())/60
dist_df['diff'] = (n.dt.total_seconds())/60

# %%
dist_df['slots'] = dist_df['diff']/5
dist_df['slots']=dist_df['slots'].astype('int64')
dist_df['bins'] = dist_df.slots.map( lambda x: np.arange(1,x+1,1) if x > 1.0 else np.arange(1,x+1))

# %%
dist_df['start'] = dist_df.start_date.dt.date
dist_df['start'] = pd.to_datetime(dist_df.start,format='%Y\%m\%d')

# %%
def explode(df, lst_cols, fill_value=''):
    if lst_cols and not isinstance(lst_cols, list):
        lst_cols = [lst_cols]
    idx_cols = df.columns.difference(lst_cols)
    lens = df[lst_cols[0]].str.len()
    if (lens > 0).all():
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .loc[:, df.columns]
    else:
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .append(df.loc[lens==0, idx_cols]).fillna(fill_value) \
          .loc[:, df.columns]

# %%
new_df=explode(dist_df, ['bins'], fill_value='')

# %%
new_df['bins'] = (new_df.start_from_fc + pd.to_timedelta(5*(new_df['bins']), unit='m'))
new_df['bins1'] = new_df.bins - pd.to_timedelta(5, unit='m')

# %%
new_df[new_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [asset_id, start_date, end_date, geometry, start_from_fc, end_from_fc, diff, slots, bins, start, bins1]
# Index: []

# %%
new_df.groupby(['bins1','bins','asset_id','geometry']).count()[['start_from_fc']]
# Out:
#                                                                                                           start_from_fc
# bins1               bins                asset_id      geometry
# 2018-08-10 23:30:00 2018-08-10 23:35:00 SENSITY-kc-10 {"type":"Polygon","coordinates":[[[-94.58340624...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58340723...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58340879...              1
#                                         SENSITY-kc-12 {"type":"Polygon","coordinates":[[[-94.58351305...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58351797...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58352497...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58352696...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58352923...              1
#                                         SENSITY-kc-14 {"type":"Polygon","coordinates":[[[-94.58338194...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58338265...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58338927...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58339447...              1
#                                         SENSITY-kc-18 {"type":"Polygon","coordinates":[[[-94.58372803...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58372920...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58380697...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58380735...              1
#                                         SENSITY-kc-2  {"type":"Polygon","coordinates":[[[-94.58363390...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58363456...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58363955...              1
#                                         SENSITY-kc-22 {"type":"Polygon","coordinates":[[[-94.58075470...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58077124...              1
#                                         SENSITY-kc-23 {"type":"Polygon","coordinates":[[[-94.58306831...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58345988...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58352863...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58360152...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58367349...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58374716...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58381467...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58388230...              1
#                                         SENSITY-kc-8  {"type":"Polygon","coordinates":[[[-94.58349362...              1
# ...                                                                                                                 ...
# 2018-11-26 15:35:00 2018-11-26 15:40:00 SENSITY-kc-6  {"type":"Polygon","coordinates":[[[-94.58354635...              1
#                                         SENSITY-kc-9  {"type":"Polygon","coordinates":[[[-94.58366620...              1
# 2018-11-26 15:40:00 2018-11-26 15:45:00 SENSITY-kc-11 {"type":"Polygon","coordinates":[[[-94.58358652...              1
#                                         SENSITY-kc-12 {"type":"Polygon","coordinates":[[[-94.58349017...              1
#                                         SENSITY-kc-14 {"type":"Polygon","coordinates":[[[-94.58334369...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58335069...              1
#                                         SENSITY-kc-15 {"type":"Polygon","coordinates":[[[-94.58343704...              1
#                                         SENSITY-kc-2  {"type":"Polygon","coordinates":[[[-94.58364659...              1
#                                         SENSITY-kc-6  {"type":"Polygon","coordinates":[[[-94.58353101...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58353446...              1
# 2018-11-26 15:45:00 2018-11-26 15:50:00 SENSITY-kc-12 {"type":"Polygon","coordinates":[[[-94.58349017...              1
#                                         SENSITY-kc-15 {"type":"Polygon","coordinates":[[[-94.58343704...              1
#                                         SENSITY-kc-2  {"type":"Polygon","coordinates":[[[-94.58364886...              1
#                                         SENSITY-kc-5  {"type":"Polygon","coordinates":[[[-94.58406407...              1
#                                         SENSITY-kc-6  {"type":"Polygon","coordinates":[[[-94.58353101...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58353446...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58354330...              1
#                                         SENSITY-kc-9  {"type":"Polygon","coordinates":[[[-94.58367287...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58367820...              1
# 2018-11-26 15:50:00 2018-11-26 15:55:00 SENSITY-kc-10 {"type":"Polygon","coordinates":[[[-94.58341227...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58342777...              1
#                                         SENSITY-kc-11 {"type":"Polygon","coordinates":[[[-94.58358263...              1
#                                         SENSITY-kc-12 {"type":"Polygon","coordinates":[[[-94.58349017...              1
#                                         SENSITY-kc-5  {"type":"Polygon","coordinates":[[[-94.58406407...              1
#                                         SENSITY-kc-6  {"type":"Polygon","coordinates":[[[-94.58354330...              1
#                                         SENSITY-kc-8  {"type":"Polygon","coordinates":[[[-94.58352895...              1
#                                         SENSITY-kc-9  {"type":"Polygon","coordinates":[[[-94.58367287...              1
#                                                       {"type":"Polygon","coordinates":[[[-94.58367820...              1
# 2018-11-26 15:55:00 2018-11-26 16:00:00 SENSITY-kc-11 {"type":"Polygon","coordinates":[[[-94.58358263...              1
#                                         SENSITY-kc-8  {"type":"Polygon","coordinates":[[[-94.58352895...              1
#
# [2020993 rows x 1 columns]

# %%
df_5min = new_df.groupby(['bins1','bins','asset_id','geometry']).count()[['start_from_fc']].add_suffix('_Count').reset_index()

# %%
df_5min.head()
# Out:
#                 bins1                bins       asset_id  \
# 0 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10
# 1 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10
# 2 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10
# 3 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-12
# 4 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-12
#
#                                             geometry  start_from_fc_Count
# 0  {"type":"Polygon","coordinates":[[[-94.5834062...                    1
# 1  {"type":"Polygon","coordinates":[[[-94.5834072...                    1
# 2  {"type":"Polygon","coordinates":[[[-94.5834087...                    1
# 3  {"type":"Polygon","coordinates":[[[-94.5835130...                    1
# 4  {"type":"Polygon","coordinates":[[[-94.5835179...                    1

# %%
df_5min['geometry'] = df_5min.geometry.apply(lambda x: json.loads(x))

# %%
df_5min.head(5)
# Out:
#                 bins1                bins       asset_id  \
# 0 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10
# 1 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10
# 2 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10
# 3 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-12
# 4 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-12
#
#                                             geometry  start_from_fc_Count
# 0  {'type': 'Polygon', 'coordinates': [[[-94.5834...                    1
# 1  {'type': 'Polygon', 'coordinates': [[[-94.5834...                    1
# 2  {'type': 'Polygon', 'coordinates': [[[-94.5834...                    1
# 3  {'type': 'Polygon', 'coordinates': [[[-94.5835...                    1
# 4  {'type': 'Polygon', 'coordinates': [[[-94.5835...                    1

# %%
df_5min['temp'] = df_5min.geometry.apply(lambda x: list(x.values())[1][0])

# %%
df_5min['poly_latitide']=df_5min.temp.apply(lambda x: list([x[0][0],x[1][0],x[2][0],x[3][0],x[4][0]]))
df_5min['poly_longitude']=df_5min.temp.apply(lambda x: list([x[0][1],x[1][1],x[2][1],x[3][1],x[4][1]]))

# %%
df_5min['mc']=(df_5min.apply(lambda x: (list(zip(x[6], x[7]))), axis=1))
df_5min['mc']=df_5min['mc'].apply(Polygon)

# %%
df_5min.head()
# Out:
#                 bins1                bins       asset_id  \
# 0 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10
# 1 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10
# 2 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10
# 3 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-12
# 4 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-12
#
#                                             geometry  start_from_fc_Count  \
# 0  {'type': 'Polygon', 'coordinates': [[[-94.5834...                    1
# 1  {'type': 'Polygon', 'coordinates': [[[-94.5834...                    1
# 2  {'type': 'Polygon', 'coordinates': [[[-94.5834...                    1
# 3  {'type': 'Polygon', 'coordinates': [[[-94.5835...                    1
# 4  {'type': 'Polygon', 'coordinates': [[[-94.5835...                    1
#
#                                                 temp  \
# 0  [[-94.5834062421616, 39.09438467559006], [-94....
# 1  [[-94.58340723278391, 39.094330998240316], [-9...
# 2  [[-94.5834087918651, 39.0942812171699], [-94.5...
# 3  [[-94.58351305730527, 39.095150612952516], [-9...
# 4  [[-94.58351797524573, 39.095258714384116], [-9...
#
#                                        poly_latitide  \
# 0  [-94.5834062421616, -94.58340906848268, -94.58...
# 1  [-94.58340723278391, -94.58340922355299, -94.5...
# 2  [-94.5834087918651, -94.58340941578419, -94.58...
# 3  [-94.58351305730527, -94.58351361678675, -94.5...
# 4  [-94.58351797524573, -94.58351876023067, -94.5...
#
#                                       poly_longitude  \
# 0  [39.09438467559006, 39.09433597524264, 39.0943...
# 1  [39.094330998240316, 39.094287449158564, 39.09...
# 2  [39.0942812171699, 39.09424022838295, 39.09424...
# 3  [39.095150612952516, 39.095105228331306, 39.09...
# 4  [39.095258714384116, 39.09520723787477, 39.095...
#
#                                                   mc
# 0  POLYGON ((-94.5834062421616 39.09438467559006,...
# 1  POLYGON ((-94.58340723278391 39.09433099824032...
# 2  POLYGON ((-94.5834087918651 39.0942812171699, ...
# 3  POLYGON ((-94.58351305730527 39.09515061295252...
# 4  POLYGON ((-94.58351797524573 39.09525871438412...

# %%
df_5min.drop(columns='poly_latitide',inplace=True)
df_5min.drop(columns='poly_longitude',inplace=True)

# %%
df_5min.drop(columns='temp',inplace=True)
df_5min.drop(columns='geometry',inplace=True)

# %%
df_5min.head(5)
# Out:
#                 bins1                bins       asset_id  start_from_fc_Count  \
# 0 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10                    1
# 1 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10                    1
# 2 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-10                    1
# 3 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-12                    1
# 4 2018-08-10 23:30:00 2018-08-10 23:35:00  SENSITY-kc-12                    1
#
#                                                   mc
# 0  POLYGON ((-94.5834062421616 39.09438467559006,...
# 1  POLYGON ((-94.58340723278391 39.09433099824032...
# 2  POLYGON ((-94.5834087918651 39.0942812171699, ...
# 3  POLYGON ((-94.58351305730527 39.09515061295252...
# 4  POLYGON ((-94.58351797524573 39.09525871438412...

# %%
crs = {'init': 'epsg:4326'}
gdf = gp.GeoDataFrame(df_5min, crs=crs ,geometry='mc')

# %%
new_df.loc[(new_df['asset_id']=='SENSITY-kc-23') &\
           (new_df['bins1']=='2018-11-03 21:45:00')\
          & new_df.geometry.str.contains('94.58387299795793')]
# Out:
#               asset_id          start_date            end_date  \
# 1691080  SENSITY-kc-23 2018-11-03 21:44:09 2018-11-03 21:46:02
# 1691082  SENSITY-kc-23 2018-11-03 21:45:27 2018-11-03 21:47:02
#
#                                                   geometry  \
# 1691080  {"type":"Polygon","coordinates":[[[-94.5838729...
# 1691082  {"type":"Polygon","coordinates":[[[-94.5838729...
#
#               start_from_fc         end_from_fc  diff  slots  \
# 1691080 2018-11-03 21:40:00 2018-11-03 21:50:00  10.0      2
# 1691082 2018-11-03 21:45:00 2018-11-03 21:50:00   5.0      1
#
#                        bins      start               bins1
# 1691080 2018-11-03 21:50:00 2018-11-03 2018-11-03 21:45:00
# 1691082 2018-11-03 21:50:00 2018-11-03 2018-11-03 21:45:00

# %%
new_df.loc[(new_df['asset_id']=='SENSITY-kc-15') &\
           (new_df.bins1.isin(['2018-09-26 03:20:00','2018-09-26 03:25:00','2018-09-26 03:30:00']))\
          & new_df.geometry.str.contains('94.58354627591267')].sort_values(by=['bins1'],ascending=True)
# Out:
#              asset_id          start_date            end_date  \
# 858195  SENSITY-kc-15 2018-09-26 03:24:15 2018-09-26 03:32:53
# 944742  SENSITY-kc-15 2018-09-26 03:23:16 2018-09-26 03:32:53
# 858196  SENSITY-kc-15 2018-09-26 03:24:15 2018-09-26 03:32:53
# 944743  SENSITY-kc-15 2018-09-26 03:23:16 2018-09-26 03:32:53
# 858197  SENSITY-kc-15 2018-09-26 03:24:15 2018-09-26 03:32:53
# 944744  SENSITY-kc-15 2018-09-26 03:23:16 2018-09-26 03:32:53
#
#                                                  geometry       start_from_fc  \
# 858195  {"type":"Polygon","coordinates":[[[-94.5835462... 2018-09-26 03:20:00
# 944742  {"type":"Polygon","coordinates":[[[-94.5835462... 2018-09-26 03:20:00
# 858196  {"type":"Polygon","coordinates":[[[-94.5835462... 2018-09-26 03:20:00
# 944743  {"type":"Polygon","coordinates":[[[-94.5835462... 2018-09-26 03:20:00
# 858197  {"type":"Polygon","coordinates":[[[-94.5835462... 2018-09-26 03:20:00
# 944744  {"type":"Polygon","coordinates":[[[-94.5835462... 2018-09-26 03:20:00
#
#                end_from_fc  diff  slots                bins      start  \
# 858195 2018-09-26 03:35:00  15.0      3 2018-09-26 03:25:00 2018-09-26
# 944742 2018-09-26 03:35:00  15.0      3 2018-09-26 03:25:00 2018-09-26
# 858196 2018-09-26 03:35:00  15.0      3 2018-09-26 03:30:00 2018-09-26
# 944743 2018-09-26 03:35:00  15.0      3 2018-09-26 03:30:00 2018-09-26
# 858197 2018-09-26 03:35:00  15.0      3 2018-09-26 03:35:00 2018-09-26
# 944744 2018-09-26 03:35:00  15.0      3 2018-09-26 03:35:00 2018-09-26
#
#                      bins1
# 858195 2018-09-26 03:20:00
# 944742 2018-09-26 03:20:00
# 858196 2018-09-26 03:25:00
# 944743 2018-09-26 03:25:00
# 858197 2018-09-26 03:30:00
# 944744 2018-09-26 03:30:00

# %%
gdf.rename(columns={'bins1':'start_time','bins':'end_time','asset_id':'sensor_id','start_from_fc_Count':'no_of_cars'},inplace=True)

# %%
import folium
m = folium.Map([39.10087297922868, -94.58354627591267], zoom_start=5, tiles='cartodbpositron')
folium.GeoJson(gdf.loc[gdf['no_of_cars']>1].mc).add_to(m)
folium.LatLngPopup().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gdf.loc[(gdf['sensor_id']=='SENSITY-kc-14') & (gdf['start_time']=='2018-11-03 13:30:00')].plot()

# %%
import folium
# 'Stamen Toner'
#  Stamen Terrain
# Mapbox Bright
# cartodbpositron
m = folium.Map([39.10087297922868, -94.58354627591267], zoom_start=5, tiles='cartodbpositron')
folium.GeoJson(gdf.loc[(gdf['sensor_id']=='SENSITY-kc-14') & (gdf['start_time']=='2018-11-03 13:30:00')].mc).add_to(m)
folium.LatLngPopup().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
temp_df1=gdf.loc[(gdf['start_time']=='2018-11-03 13:30:00')]
temp_df=gdf.loc[(gdf['sensor_id']=='SENSITY-kc-14') & (gdf['start_time']=='2018-11-03 13:30:00')]
temp_df1['mc1']=temp_df1.mc.apply(lambda x : Point(list(x.exterior.coords)))
from folium import IFrame
from folium.plugins import MarkerCluster
map = folium.Map([39.10087297922868, -94.58354627591267], zoom_start = 14)

def add_point_clusters(mapobj, gdf, popup_field_list):
    #Create empty lists to contain the point coordinates and the point pop-up information
    coords, popups = [], [] 
    #Loop through each record in the GeoDataFrame
    for i, row in gdf.iterrows():
        #Append lat and long coordinates to "coords" list
        coords.append([row.mc1.y, row.mc1.x])
#         coords.append(row.mc1)
        #Create a string of HTML code used in the IFrame popup
        #Join together the fields in "popup_field_list" with a linebreak between them
        label = '<br>'.join([row[field] for field in popup_field_list])
        #Append an IFrame that uses the HTML string to the "popups" list 
        popups.append(IFrame(label, width = 300, height = 100))
        
    #Create a Folium feature group for this layer, since we will be displaying multiple layers
    pt_lyr = folium.FeatureGroup(name = 'pt_lyr')
    
    #Add the clustered points of crime locations and popups to this layer
    pt_lyr.add_children(MarkerCluster(locations = coords, popups = popups))
    
    #Add this point layer to the map object
    mapobj.add_children(pt_lyr)
    return mapobj

#Update choropleth with point clusters
map = add_point_clusters(map, temp_df1, ['sensor_id'])
folium.LayerControl().add_to(map) #Add layer control to toggle on/off
map.save('nov3rd1:30.html') #save HTML
map
# Out:
# /Users/neerajpadarthi/anaconda3/envs/work/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/neerajpadarthi/anaconda3/envs/work/lib/python3.5/site-packages/ipykernel_launcher.py:26: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# /Users/neerajpadarthi/anaconda3/envs/work/lib/python3.5/site-packages/ipykernel_launcher.py:29: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# download countries geojson file
# !wget --quiet https://ibm.box.com/shared/static/cto2qv7nx6yq19logfcissyy4euo8lho.json -O world_countries.json
    
print('GeoJSON file downloaded!')
# Out:
# /bin/sh: wget: command not found
# GeoJSON file downloaded!

# %%
world_geo = r'world_countries.json' # geojson file

# create a plain world map
world_map = folium.Map([39.10087297922868, -94.58354627591267], zoom_start=14, tiles='cartodbpositron')

# generate choropleth map using the total immigration of each country to Canada from 1980 to 2013
world_map.choropleth(
    geo_data=world_geo,
    data=temp_df,
    columns=temp_df.sensor_id,
    key_on='feature.properties.name',
    fill_color='YlOrRd', 
    fill_opacity=0.1, 
    line_opacity=0.2,
    legend_name='Immigration to Canada'
)

# display map
world_map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-da3cff618ead> in <module>
#      13     fill_opacity=0.1,
#      14     line_opacity=0.2,
# ---> 15     legend_name='Immigration to Canada'
#      16 )
#      17
#
# ~/anaconda3/envs/work/lib/python3.5/site-packages/folium/folium.py in choropleth(self, *args, **kwargs)
#     433         )
#     434         from folium.features import Choropleth
# --> 435         self.add_child(Choropleth(*args, **kwargs))
#     436
#     437     def keep_in_front(self, *args):
#
# ~/anaconda3/envs/work/lib/python3.5/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#     866         if hasattr(data, 'set_index'):
#     867             # This is a pd.DataFrame
# --> 868             color_data = data.set_index(columns[0])[columns[1]].to_dict()
#     869         elif hasattr(data, 'to_dict'):
#     870             # This is a pd.Series
#
# ~/anaconda3/envs/work/lib/python3.5/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~/anaconda3/envs/work/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
temp_df
# Out:
# Empty GeoDataFrame
# Columns: [start_time, end_time, sensor_id, no_of_cars, mc]
# Index: []

# %%
import folium
# 'Stamen Toner'
#  Stamen Terrain
# Mapbox Bright
# cartodbpositron
m = folium.Map([39.10087297922868, -94.58354627591267], zoom_start=5, tiles='cartodbpositron')
colormap = temp_df.linear.Set1_09.scale(0, 35).to_step(10)
colormap.caption = 'A colormap caption'
m.add_child(colormap)
m
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-2b6a1265fb8e> in <module>
#       5 # cartodbpositron
#       6 m = folium.Map([39.10087297922868, -94.58354627591267], zoom_start=5, tiles='cartodbpositron')
# ----> 7 colormap = temp_df.linear.Set1_09.scale(0, 35).to_step(10)
#       8 colormap.caption = 'A colormap caption'
#       9 m.add_child(colormap)
#
# ~/anaconda3/envs/work/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'GeoDataFrame' object has no attribute 'linear'

# %%
m = folium.Map([39.10087297922868, -94.58354627591267], tiles='cartodbpositron', zoom_start=9)

folium.GeoJson(
    temp_df.mc,
    style_function=lambda feature: {
        'fillColor': '#FF0000',
        'color': 'black',
        'weight': 3,
        'dashArray': '5,5'
    }
).add_to(m)

# m.save(os.path.join('results', 'Colormaps_0.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#gp.overlay(temp_df1, temp_df, how = 'intersection')

# %%
g=gdf.loc[(gdf['sensor_id']=='SENSITY-kc-14') & (gdf['start_time']=='2018-11-03 13:30:00') & ()]

# %%
h=gdf.loc[(gdf['sensor_id']=='SENSITY-kc-14') & (gdf['start_time']=='2018-11-03 13:30:00')][:50]

# %%
g=gdf.loc[1767554:1767554.5][['sensor_id','start_time','end_time','mc']]

# %%
crs = {'init': 'epsg:4326'}
gdfh = gp.GeoDataFrame(h, crs=crs ,geometry='mc')

# %%
crs = {'init': 'epsg:4326'}
gdfg = gp.GeoDataFrame(g, crs=crs ,geometry='mc')

# %%
g

# %%
print(gdfg.mc)
# Out:
# 1767554    POLYGON ((-94.58334483732568 39.09804596366607...
# Name: mc, dtype: object

# %%
import folium
# 'Stamen Toner'
#  Stamen Terrain
# Mapbox Bright
# cartodbpositron
m = folium.Map([39.10087297922868, -94.58354627591267], zoom_start=12, tiles='cartodbpositron')
folium.GeoJson(gdfg.mc).add_to(m)
folium.LatLngPopup().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !git clone https://github.com/granularag/pyspatial.git
# !cd pyspatial
# !pip install -r requirements.txt
# !pip install .
# !cd pyspatial
# !pwd
# Out:
# /Users/neerajpadarthi/Neeraj/2nd Sem/thesisProject

# %%
op= gp.overlay( h,g, how='intersection')

# %%
op.plot(ax=h.plot(column = "sensor_id"), color = "red")

# %%
data_overlaps=gp.GeoDataFrame(crs=h.crs)
for index, row in h.iterrows():
    data_temp1=h.loc[h.mc!=row.mc,]
    # check if intersection occured
    overlaps=data_temp1[data_temp1.geometry.overlaps(row.mc)]['mc'].tolist()
    print((overlaps))
    if len(overlaps)>0:
        temp_list=[]
        # compare the area with threshold
        for y in overlaps:
            temp_area=gp.overlay(h.loc[h.mc==y,],h.loc[h.mc==row.mc,],how='difference')
#             temp_area.head(5)
#             temp_area=temp_area.loc[temp_area.geometry.area>=9e-9]
            if temp_area.shape[0]>0:
                print()
                data_overlaps=gp.GeoDataFrame(pd.concat([temp_area,data_overlaps],ignore_index=True),crs=h.crs)
# get unique of list id
# data_overlaps['sorted']=data_overlaps.apply(lambda y: sorted([y['id_1'],y['id_2']]),axis=1)
# data_overlaps['sorted']=data_overlaps.sorted.apply(lambda y: ''.join(y))
# data_overlaps=data_overlaps.drop_duplicates('sorted')
# data_overlaps=data_overlaps.reset_index()[['id_1','id_2','geometry']]

# %%
ax=h.plot(figsize=(12, 12),alpha=0.7)
data_overlaps.plot(ax=ax,color='red')

# %%
q=gdf.loc[gdf['sensor_id']=='SENSITY-kc-10']
w=gdf.loc[gdf['sensor_id']=='SENSITY-kc-12']

# %%
crs = {'init': 'epsg:4326'}
gdfq = gp.GeoDataFrame(q, crs=crs ,geometry='mc')
crs = {'init': 'epsg:4326'}
gdfw = gp.GeoDataFrame(w, crs=crs ,geometry='mc')

# %%
op= gp.overlay( gdfq, gdfw, how='intersection')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-9496cf67273a> in <module>
# ----> 1 op= gp.overlay( gdfq, gdfw, how='intersection')
#
# ~/anaconda3/envs/work/lib/python3.5/site-packages/geopandas/tools/overlay.py in overlay(df1, df2, how, make_valid, use_sindex)
#     374         result = dfunion[dfunion['__idx1'].notnull()].copy()
#     375         result.reset_index(drop=True, inplace=True)
# --> 376     result.drop(['__idx1', '__idx2'], axis=1, inplace=True)
#     377     return result
#
# ~/anaconda3/envs/work/lib/python3.5/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/envs/work/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~/anaconda3/envs/work/lib/python3.5/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~/anaconda3/envs/work/lib/python3.5/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['__idx1' '__idx2'] not found in axis"

# %%
g=gdf.loc[(gdf['sensor_id']=='SENSITY-kc-14') & (gdf['start_time']=='2018-11-03 13:30:00')][2:3]
h=gdf.loc[(gdf['sensor_id']=='SENSITY-kc-14') & (gdf['start_time']=='2018-11-03 13:30:00')][3:4]
# h['__idx1']=""
# h['__idx2']=""
# g['__idx1']=""
# g['__idx2']=""
crs = {'init': 'epsg:4326'}
gdfg = gp.GeoDataFrame(g, crs=crs ,geometry='mc')
gdfh = gp.GeoDataFrame(h, crs=crs ,geometry='mc')

# %%
op= gp.overlay( gdfg, gdfh, how='intersection')

# %%
op
# Out:
#          start_time_1          end_time_1    sensor_id_1  no_of_cars_1  \
# 0 2018-11-03 13:30:00 2018-11-03 13:35:00  SENSITY-kc-14             1
#
#          start_time_2          end_time_2    sensor_id_2  no_of_cars_2  \
# 0 2018-11-03 13:30:00 2018-11-03 13:35:00  SENSITY-kc-14             1
#
#                                             geometry
# 0  POLYGON ((-94.58331542143659 39.09828968722022...

# %%
gdfh.geometry.overlaps(gdfg.mc)
# Out:
# 1767519    False
# 1767520    False
# dtype: bool

# %%
g
# Out:
#                  start_time            end_time      sensor_id  no_of_cars  \
# 1767519 2018-11-03 13:30:00 2018-11-03 13:35:00  SENSITY-kc-14           1
#
#                                                         mc
# 1767519  POLYGON ((-94.58331528258682 39.0982896839542,...

# %%
h
# Out:
#                  start_time            end_time      sensor_id  no_of_cars  \
# 1767520 2018-11-03 13:30:00 2018-11-03 13:35:00  SENSITY-kc-14           1
#
#                                                         mc
# 1767520  POLYGON ((-94.58331664534269 39.09826522440721...

# %%
ax=g.plot(figsize=(12, 12),alpha=0.3,color='#D3D3D3')
h.plot(ax=ax,color='#FFA07A')

ax=g.plot(figsize=(12, 12),alpha=0.3,color='#D3D3D3')
op.plot(ax=ax,color='#FFA07A')

# op.plot()

# %%
k=gdf.loc[(gdf['sensor_id']=='SENSITY-kc-5') & (gdf['start_time']=='2018-11-03 13:30:00')]
k.insert(0, 'new_id', range(100, 100 + len(k)))
crs = {'init': 'epsg:4326'}
gdfk = gp.GeoDataFrame(g, crs=crs ,geometry='mc')

# %%
data_overlaps=gp.GeoDataFrame(crs=k.crs)
for index, row in k.iterrows():
    data_temp1=k.loc[k.new_id!=row.new_id]
    print('data temp1',row.new_id,(data_temp1.new_id).tolist())
    overlaps=data_temp1[data_temp1.geometry.overlaps(row.mc)]['new_id'].tolist()
    print('overlapping data for',row.new_id,overlaps)
    if len(overlaps)>0:
        temp_list=[]
        # compare the area with threshold
        for y in overlaps:
            print(y,row.new_id)
            temp_area=gp.overlay(k.loc[k.new_id==y],k.loc[k.new_id==row.new_id],how='intersection')
#             print([temp_area.new_id_1])
#             print('here ',temp_area.new_id_1)
#             print('here ',temp_area.new_id_2)
            data_overlaps=gp.GeoDataFrame(pd.concat([temp_area,data_overlaps],ignore_index=True),crs=k.crs)
data_overlaps['sorted']=data_overlaps.apply(lambda y: sorted([y['new_id_1'],y['new_id_2']]),axis=1)
data_overlaps['sorted']=data_overlaps.sorted.astype('str').apply(lambda y:' '.join(y))
data_overlaps=data_overlaps.drop_duplicates('sorted')
data_overlaps=data_overlaps.reset_index()[['new_id_1','new_id_2','geometry']]
# Out:
# data temp1 100 [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114]
# overlapping data for 100 [101, 102, 103, 104]
# 101 100
# 102 100
# 103 100
# 104 100
# data temp1 101 [100, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114]
# overlapping data for 101 [100, 102, 103, 104]
# 100 101
# 102 101
# 103 101
# 104 101
# data temp1 102 [100, 101, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114]
# overlapping data for 102 [100, 101, 103]
# 100 102
# 101 102
# 103 102
# data temp1 103 [100, 101, 102, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114]
# overlapping data for 103 [100, 101, 102, 104]
# 100 103
# 101 103
# 102 103
# 104 103
# data temp1 104 [100, 101, 102, 103, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114]
# overlapping data for 104 [100, 101, 103]
# 100 104
# 101 104
# 103 104
# data temp1 105 [100, 101, 102, 103, 104, 106, 107, 108, 109, 110, 111, 112, 113, 114]
# overlapping data for 105 []
# data temp1 106 [100, 101, 102, 103, 104, 105, 107, 108, 109, 110, 111, 112, 113, 114]
# overlapping data for 106 [107]
# 107 106
# data temp1 107 [100, 101, 102, 103, 104, 105, 106, 108, 109, 110, 111, 112, 113, 114]
# overlapping data for 107 [106]
# 106 107
# data temp1 108 [100, 101, 102, 103, 104, 105, 106, 107, 109, 110, 111, 112, 113, 114]
# overlapping data for 108 [109, 110, 111, 112, 113, 114]
# 109 108
# 110 108
# 111 108
# 112 108
# 113 108
# 114 108
# data temp1 109 [100, 101, 102, 103, 104, 105, 106, 107, 108, 110, 111, 112, 113, 114]
# overlapping data for 109 [108, 110, 111, 112, 113, 114]
# 108 109
# 110 109
# 111 109
# 112 109
# 113 109
# 114 109
# data temp1 110 [100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 111, 112, 113, 114]
# overlapping data for 110 [108, 109, 111, 112, 113, 114]
# 108 110
# 109 110
# 111 110
# 112 110
# 113 110
# 114 110
# data temp1 111 [100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 112, 113, 114]
# overlapping data for 111 [108, 109, 110, 112, 113, 114]
# 108 111
# 109 111
# 110 111
# 112 111
# 113 111
# 114 111
# data temp1 112 [100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 113, 114]
# overlapping data for 112 [108, 109, 110, 111, 113, 114]
# 108 112
# 109 112
# 110 112
# 111 112
# 113 112
# 114 112
# data temp1 113 [100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 114]
# overlapping data for 113 [108, 109, 110, 111, 112, 114]
# 108 113
# 109 113
# 110 113
# 111 113
# 112 113
# 114 113
# data temp1 114 [100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113]
# overlapping data for 114 [108, 109, 110, 111, 112, 113]
# 108 114
# 109 114
# 110 114
# 111 114
# 112 114
# 113 114

# %%
data_overlaps.sort_values(by='new_id_1')
# Out:
#     new_id_1  new_id_2                                           geometry
# 30       100       101  POLYGON ((-94.58393669541891 39.09032078250237...
# 27       100       103  POLYGON ((-94.58393896072556 39.09032086474514...
# 29       100       102  POLYGON ((-94.58393780475488 39.09032082277721...
# 24       100       104  POLYGON ((-94.5839932281586 39.09032283494359,...
# 28       101       102  POLYGON ((-94.58399834944271 39.09032251270001...
# 26       101       103  POLYGON ((-94.58393904655823 39.0903196926411,...
# 23       101       104  POLYGON ((-94.5839622659596 39.09033789474575,...
# 25       102       103  POLYGON ((-94.58393902662787 39.09031996480369...
# 22       103       104  POLYGON ((-94.58399670389262 39.09032294623432...
# 21       106       107  POLYGON ((-94.58412202261195 39.09032905090752...
# 17       108       111  POLYGON ((-94.58416274858074 39.09033067716818...
# 14       108       112  POLYGON ((-94.58416468952875 39.09033076665786...
# 10       108       113  POLYGON ((-94.58416555236337 39.09033080643987...
# 5        108       114  POLYGON ((-94.58421615602533 39.09033477403919...
# 19       108       110  POLYGON ((-94.58416013805487 39.09033055680683...
# 20       108       109  POLYGON ((-94.58416005102249 39.0903305527941,...
# 13       109       112  POLYGON ((-94.58416480969892 39.09032902031351...
# 9        109       113  POLYGON ((-94.5841656569381 39.0903290515436, ...
# 16       109       111  POLYGON ((-94.58416285060129 39.09032894809921...
# 4        109       114  POLYGON ((-94.58422423925471 39.09033502047632...
# 18       109       110  POLYGON ((-94.58418243928919 39.09032967015784...
# 15       110       111  POLYGON ((-94.58416284578898 39.09032902965939...
# 8        110       113  POLYGON ((-94.58416565277427 39.09032912141787...
# 3        110       114  POLYGON ((-94.58422417391625 39.09033501848432...
# 12       110       112  POLYGON ((-94.58416480464948 39.09032909369324...
# 11       111       112  POLYGON ((-94.5841648896254 39.09032785880076,...
# 7        111       113  POLYGON ((-94.58416572622755 39.09032788877881...
# 2        111       114  POLYGON ((-94.58422468185471 39.09033503397007...
# 6        112       113  POLYGON ((-94.58422865842071 39.09032934591396...
# 1        112       114  POLYGON ((-94.58422825951385 39.09033514304381...
# 0        113       114  POLYGON ((-94.5842298186064 39.09033519057658,...

# %%
data_overlaps.loc[data_overlaps['new_id_1']==101]['new_id_2'].tolist()
# Out:
# [104, 103, 102]

# %%
ax=k.plot(figsize=(12, 12),alpha=0.3)
data_overlaps.plot(ax=ax,color='#FFA07A')

# %%
import folium
# 'Stamen Toner'
#  Stamen Terrain
# Mapbox Bright
# cartodbpositron


m = folium.Map([39.0903, -94.58404627591267], zoom_start=17, tiles='cartodbpositron')

folium.GeoJson(k.mc
              ,style_function=lambda feature: {
        'color': 'green',
        'weight': 3,
    }).add_to(m)
folium.GeoJson(data_overlaps.geometry
             ,style_function=lambda feature: {
        'color': 'red',
        'weight': 3,
    } ).add_to(m)
folium.LatLngPopup().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data_overlaps.loc[(data_overlaps.new_id_2.isin([104, 103, 102, 101])) & \
                 (data_overlaps.new_id_1.isin([100]))].plot()

# %%
k.loc[(k.new_id.isin([104, 103, 102, 101,100,105]))].plot()

# %%
kanton_map = folium.Map(location=[39.0903, -94.58404627591267],
                   tiles='cartodbpositron', zoom_start=11)
kanton_map
kanton_map.choropleth(geo_data='KSB.geojson')
kanton_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
cdf = pd.read_csv('sensity_events.csv')

# %%
cdf.head()
# Out:
#                                                 uuid       asset_id  \
# 0  SENSITY-kc-23-40D98DC1-41F8-40EE-BBB8-E44DE41C...  SENSITY-kc-23
# 1  SENSITY-kc-22-E5EBBB3A-05E4-4D9C-97CB-26542918...  SENSITY-kc-22
# 2  SENSITY-kc-10-C4D472BA-65CA-4D2B-A6C0-9C3981CD...  SENSITY-kc-10
# 3  SENSITY-kc-12-4C26D1EC-4CCE-4E9A-87D1-D93149F5...  SENSITY-kc-12
# 4  SENSITY-kc-9-CDDB22AD-31F6-4A11-BC94-CCC6602575A1   SENSITY-kc-9
#
#                 start_time                    end_time session_type  \
# 0  2018-08-10 23:33:26.081    2018-08-10 23:33:55.9371          car
# 1  2018-08-10 23:34:58.454  2018-08-10 23:36:08.256733          car
# 2  2018-08-10 23:33:40.424  2018-08-10 23:36:25.890125          car
# 3  2018-08-10 23:34:44.149  2018-08-10 23:38:53.829785          car
# 4  2018-08-10 23:37:38.946  2018-08-10 23:39:01.415632          car
#
#     latitude  longitude                                           geometry
# 0  39.109786 -94.583482  {"type":"Polygon","coordinates":[[[-94.5834598...
# 1  39.109536 -94.580771  {"type":"Polygon","coordinates":[[[-94.5807547...
# 2  39.094360 -94.583396  {"type":"Polygon","coordinates":[[[-94.5834062...
# 3  39.095302 -94.583515  {"type":"Polygon","coordinates":[[[-94.5835249...
# 4  39.092984 -94.583621  {"type":"Polygon","coordinates":[[[-94.5836287...

# %%
cdf['longitude']  cdf['latitude']
# Out:
#   File "<ipython-input-491-ae00518c1d6b>", line 1
#     cdf['longitude'] ',' cdf['latitude']
#                        ^
# SyntaxError: invalid syntax

# %%
([cdf['longitude'][0],cdf['latitude'][0]])
# Out:
# [-94.5834816617635, 39.10978592600429]

# %%
cdf.apply(lambda y: list([y['longitude'],y['latitude']]),axis=1).tolist()
# Out:
# [[-94.5834816617635, 39.10978592600429],
#  [-94.5807712566161, 39.1095360461796],
#  [-94.5833964061043, 39.094359928977106],
#  [-94.5835153236837, 39.0953022307935],
#  [-94.58362129721941, 39.0929837929106],
#  [-94.58338088877122, 39.0974861273139],
#  [-94.5836028038121, 39.1081229161611],
#  [-94.5836298337034, 39.0895257143255],
#  [-94.5834952209961, 39.0955491843685],
#  [-94.5805071474366, 39.109129454214504],
#  [-94.580498134005, 39.1090956785045],
#  [-94.58348129632209, 39.0928727133682],
#  [-94.58365084178172, 39.0922724582825],
#  [-94.58340507044201, 39.094211013031504],
#  [-94.5835072577362, 39.0921933031617],
#  [-94.58350592106831, 39.0921194506509],
#  [-94.5834876143458, 39.095554197552204],
#  [-94.58336868630708, 39.097539565752605],
#  [-94.58351248811181, 39.0952116283548],
#  [-94.58338373646228, 39.0974316434289],
#  [-94.58362720210229, 39.0896774910402],
#  [-94.5834241169438, 39.0937827537638],
#  [-94.5836168492973, 39.0930182834597],
#  [-94.58349352290979, 39.100881894374204],
#  [-94.5834018491346, 39.0942014452661],
#  [-94.58349547782178, 39.109773903764896],
#  [-94.58337117685859, 39.0975563175343],
#  [-94.5833988121583, 39.0941590760623],
#  [-94.58340273812401, 39.094200630387796],
#  [-94.5830611277874, 39.1082353304453],
#  [-94.5834857886594, 39.1008819324508],
#  [-94.5834012047926, 39.0940533192649],
#  [-94.5830638861645, 39.1082353600776],
#  [-94.58365331309271, 39.0919704671543],
#  [-94.58337165085449, 39.0975994002722],
#  [-94.5839321250377, 39.1096871356748],
#  [-94.5836074227103, 39.0901850427197],
#  [-94.5833221127592, 39.098125613450605],
#  [-94.58340084523608, 39.0942604770674],
#  [-94.5838782701417, 39.090323096596606],
#  [-94.58333249062349, 39.0980855976127],
#  [-94.58421318131121, 39.0903368314983],
#  [-94.58353586477159, 39.0914758880996],
#  [-94.5833797335025, 39.097460661560795],
#  [-94.5835782857062, 39.093782394588104],
#  [-94.58341554430972, 39.0938342587788],
#  [-94.58358182415719, 39.0937211729135],
#  [-94.58358723155291, 39.0936731049355],
#  [-94.5839071034142, 39.1096964570632],
#  [-94.5836202234326, 39.093031426350606],
#  [-94.5833743197443, 39.0975991338031],
#  [-94.5833342997857, 39.0981440196787],
#  [-94.5834834451635, 39.0925421324383],
#  [-94.5835192676356, 39.0950371383809],
#  [-94.5836246456117, 39.089637429260996],
#  [-94.58048581842091, 39.1090666124432],
#  [-94.5808988958178, 39.1099039390158],
#  [-94.5836112241852, 39.0900499098454],
#  [-94.5834940643857, 39.092470444121204],
#  [-94.58361896220221, 39.0932371168832],
#  [-94.5836180768281, 39.0899126996514],
#  [-94.58359884381291, 39.090225549980204],
#  [-94.5809037345614, 39.1099049499226],
#  [-94.58350078915942, 39.0951315893372],
#  [-94.5834021983742, 39.0942011040584],
#  [-94.58340203128901, 39.0942016112484],
#  [-94.5834023049726, 39.094200918868104],
#  [-94.5835768277762, 39.093997801262105],
#  [-94.58336435355871, 39.0975157883389],
#  [-94.58357705936871, 39.0937359088451],
#  [-94.5836487429714, 39.0923158712526],
#  [-94.5835388615388, 39.091382230060894],
#  [-94.58369797041661, 39.1097400829639],
#  [-94.5836273837169, 39.0928831879758],
#  [-94.58338664020029, 39.097431410734295],
#  [-94.58367879204859, 39.108111083824],
#  [-94.5834871840163, 39.0924892213748],
#  [-94.5833324746052, 39.098197352007396],
#  [-94.58333260279561, 39.0980878287076],
#  [-94.5835161332297, 39.0950885088126],
#  [-94.58332993118161, 39.0981261671311],
#  [-94.58362528967541, 39.089588866339],
#  [-94.5805231218672, 39.109188801060796],
#  [-94.58332954145109, 39.0981408598672],
#  [-94.58365754434558, 39.0921808979491],
#  [-94.5833429396826, 39.0979870346424],
#  [-94.5831963645182, 39.1082090460808],
#  [-94.58406826693, 39.0903317518639],
#  [-94.5836230939708, 39.092937993385206],
#  [-94.583610049547, 39.090074992667105],
#  [-94.58357530595181, 39.093933086441396],
#  [-94.5833654793267, 39.0975227906955],
#  [-94.5834897842505, 39.0924907313912],
#  [-94.58362659867201, 39.089636658794106],
#  [-94.58340232634741, 39.094201075194896],
#  [-94.583384115077, 39.0974308740626],
#  [-94.5833274312488, 39.0981397099585],
#  [-94.58387808706499, 39.090325357707],
#  [-94.5837672997509, 39.1097223857905],
#  [-94.5833996819937, 39.0942601443469],
#  [-94.5838369624951, 39.08886983743],
#  [-94.58361035060992, 39.0899888870296],
#  [-94.58334371932, 39.0979793965771],
#  [-94.5836165286307, 39.090127208891396],
#  [-94.5833296946335, 39.098291553090604],
#  [-94.583577036087, 39.093772816013605],
#  [-94.58420292037641, 39.09033837892179],
#  [-94.58369242430359, 39.0913721325225],
#  [-94.5833243491235, 39.0981408879232],
#  [-94.5833832598315, 39.0974329652386],
#  [-94.58385695950581, 39.1080763690885],
#  [-94.5833311043418, 39.0981907081503],
#  [-94.58340228345449, 39.0941998621722],
#  [-94.58346368836479, 39.0932826000096],
#  [-94.58354812007539, 39.0911980347362],
#  [-94.58342596365559, 39.10088053789679],
#  [-94.58334635056299, 39.0979607176836],
#  [-94.5839527227516, 39.090329600849294],
#  [-94.5834164133684, 39.0938353860529],
#  [-94.5833634336894, 39.0975211797259],
#  [-94.58355292841159, 39.1097712816761],
#  [-94.5837729257979, 39.1097226663325],
#  [-94.5835068092294, 39.0952328690983],
#  [-94.58383696573222, 39.1080778133765],
#  [-94.5836166954866, 39.0930827446424],
#  [-94.5809010519693, 39.1099048607037],
#  [-94.5834850396772, 39.092593965546605],
#  [-94.5833443313, 39.0979799108795],
#  [-94.58334067911998, 39.0979810151651],
#  [-94.5836186918132, 39.089809457051004],
#  [-94.5836105466645, 39.0900530308845],
#  [-94.5834981657972, 39.1008789496892],
#  [-94.58343763773891, 39.1008782414585],
#  [-94.583611069837, 39.0932753683225],
#  [-94.58362658304242, 39.089940688309795],
#  [-94.58382668004721, 39.108085093857206],
#  [-94.58383460946821, 39.0889104388997],
#  [-94.5836562160779, 39.0924396461865],
#  [-94.5805010455064, 39.109118307939795],
#  [-94.5805973349783, 39.1093884249014],
#  [-94.58340223423401, 39.0942011128377],
#  [-94.5834023332482, 39.0942009066012],
#  [-94.5834023061081, 39.0942007938961],
#  [-94.58340421919229, 39.0942976508566],
#  [-94.5833191382049, 39.098382123213895],
#  [-94.5834250020739, 39.0935955318767],
#  [-94.5835497640398, 39.0912508869851],
#  [-94.5836266926028, 39.0927955489076],
#  [-94.58331621359459, 39.09841784443171],
#  [-94.58359412760642, 39.1081296110747],
#  [-94.5836462364435, 39.0925714196609],
#  [-94.583537624172, 39.0915361640419],
#  [-94.58355857464942, 39.091249960140004],
#  [-94.58077583174999, 39.109531591090004],
#  [-94.58362847382959, 39.092882796171],
#  [-94.58337093535, 39.1008778484515],
#  [-94.5832979061565, 39.100871044174205],
#  [-94.5836277992826, 39.0897213708826],
#  [-94.5834564041446, 39.0932526800212],
#  [-94.5835168668216, 39.0953023257499],
#  [-94.58361126867149, 39.089986627068],
#  [-94.5836273077915, 39.08985810301571],
#  [-94.5836973114322, 39.09145576118],
#  [-94.58395359292419, 39.090329608941396],
#  [-94.58383377552309, 39.088924302668296],
#  [-94.58347792403531, 39.0925959236281],
#  [-94.58420865554501, 39.09033736276729],
#  [-94.5839540362393, 39.0903306841781],
#  [-94.5833273918259, 39.0982924276324],
#  [-94.5835858217614, 39.093677661251],
#  [-94.58348359675041, 39.109789676504505],
#  [-94.58347950693029, 39.092794744943],
#  [-94.583663965594, 39.092015611792895],
#  [-94.58391671976369, 39.109692942461294],
#  [-94.58361459046341, 39.0932630264259],
#  [-94.58340329467909, 39.094212215865895],
#  [-94.5834730388824, 39.0929525207181],
#  [-94.5835970907623, 39.09021807007829],
#  [-94.58420261008791, 39.0903386879504],
#  [-94.5833441017414, 39.097937012474105],
#  [-94.5836137108332, 39.093239818800896],
#  [-94.5841506603652, 39.0903337415821],
#  [-94.583477123613, 39.092915113263295],
#  [-94.5833178251416, 39.0984210692803],
#  [-94.5835583246195, 39.1097711234535],
#  [-94.58357016286209, 39.094042588688104],
#  [-94.5834223688336, 39.0935919932969],
#  [-94.5833993680137, 39.0941696697205],
#  [-94.58331988138771, 39.098373338815996],
#  [-94.58382715360901, 39.0889316117509],
#  [-94.5834244530569, 39.0936478756554],
#  [-94.5836389238814, 39.089540273907105],
#  [-94.58383636223151, 39.1097114771548],
#  [-94.5830968210656, 39.109868433078205],
#  [-94.5834002428022, 39.0942606408677],
#  [-94.58375610802591, 39.108095933094],
#  [-94.58375654885491, 39.1080961500947],
#  [-94.5833400597427, 39.0980378992804],
#  [-94.5833240930735, 39.0981208033786],
#  [-94.5836223754537, 39.0897287330654],
#  [-94.5834092100562, 39.0938889232555],
#  [-94.5836183886458, 39.08986004035889],
#  [-94.58360694480601, 39.090139443528706],
#  [-94.58347798058979, 39.092964843774],
#  [-94.58347894195869, 39.0928028399008],
#  [-94.58348795915329, 39.1008809437914],
#  [-94.5836203223167, 39.0899761767403],
#  [-94.583832690323, 39.0889201859166],
#  [-94.5836878140292, 39.108109836739395],
#  [-94.5834235289276, 39.093595022165395],
#  [-94.58351004192369, 39.0952214697818],
#  [-94.5836497328149, 39.0925163492404],
#  [-94.58340191058029, 39.0942007972291],
#  [-94.58337680758379, 39.097547139687705],
#  [-94.583403179466, 39.0941997036463],
#  [-94.58351759056869, 39.1008939161193],
#  [-94.5836273550086, 39.109754609319296],
#  [-94.5807894978342, 39.10958995090171],
#  [-94.58339757503491, 39.0943089279775],
#  [-94.5838370828335, 39.108078202775005],
#  [-94.5833755724338, 39.0975444154781],
#  [-94.58350285359221, 39.0951278421693],
#  [-94.583473897204, 39.092926551335104],
#  [-94.5833786278205, 39.0975480357697],
#  [-94.58341618844229, 39.0938317726871],
#  [-94.583617983188, 39.0899788308092],
#  [-94.58383712203991, 39.0888557806216],
#  [-94.5836021643852, 39.090179380858295],
#  [-94.58347640880609, 39.0929164826473],
#  [-94.5835026669128, 39.0922491842117],
#  [-94.58351409972359, 39.092058976680896],
#  [-94.5836130284967, 39.108126869771496],
#  [-94.58377389459541, 39.109721643038604],
#  [-94.583518789283, 39.092040278053105],
#  [-94.583506720719, 39.0952982744105],
#  [-94.5834228682502, 39.0936480245172],
#  [-94.5834004422319, 39.0943070380201],
#  [-94.5834072001248, 39.100873567064],
#  [-94.58387020112629, 39.1096996324855],
#  [-94.5834022030592, 39.0942011128205],
#  [-94.583392289671, 39.1008729619106],
#  [-94.5834021028434, 39.0942010096163],
#  [-94.5833770447912, 39.097556125575],
#  [-94.5834024926499, 39.0941054643902],
#  [-94.5830427818725, 39.1082406001805],
#  [-94.5835103663551, 39.0952103090959],
#  [-94.58333215181419, 39.0981973434235],
#  [-94.583681761663, 39.108108270882504],
#  [-94.58401461673809, 39.090333854182],
#  [-94.5836257934342, 39.0898855423739],
#  [-94.58361299494258, 39.0899893254114],
#  [-94.583512725907, 39.0921916511921],
#  [-94.58360017018342, 39.0902237590755],
#  [-94.583338781995, 39.0980343690028],
#  [-94.5835056348386, 39.095125028237],
#  [-94.58377075859529, 39.1097218619023],
#  [-94.5836482583634, 39.092361512901896],
#  [-94.583482923113, 39.0928759540519],
#  [-94.58334224634329, 39.0979776602158],
#  [-94.5836111861998, 39.090133262308704],
#  [-94.5833813396274, 39.0974589028216],
#  [-94.58295887834998, 39.104040298479],
#  [-94.58306100107691, 39.108234018104504],
#  [-94.5836128787449, 39.090130978363],
#  [-94.58361039804448, 39.0899879001379],
#  [-94.5833562183021, 39.1008783292944],
#  [-94.5834268146778, 39.1008798412308],
#  [-94.58357709315929, 39.0940457146904],
#  [-94.5834025476137, 39.094198312271295],
#  [-94.5834640143734, 39.09323694347],
#  [-94.5834026515555, 39.0941980404734],
#  [-94.58343446190771, 39.1008791752515],
#  [-94.583483162358, 39.0925945660127],
#  [-94.58385516396271, 39.1080782763595],
#  [-94.5837090449579, 39.091395223584705],
#  [-94.58395444122709, 39.0903291291757],
#  [-94.58361737240591, 39.0932235207667],
#  [-94.58348269356141, 39.1097861814971],
#  [-94.5834138044286, 39.093905429987004],
#  [-94.58342278493141, 39.0935632446876],
#  [-94.58347655000591, 39.0929124532514],
#  [-94.5833167108028, 39.0984160918584],
#  [-94.5836119244664, 39.0899282681525],
#  [-94.58352803406879, 39.0916118798251],
#  [-94.5836264378739, 39.0928211896956],
#  [-94.58349351849449, 39.095552342139],
#  [-94.5837600751557, 39.1080929018428],
#  [-94.58391784261791, 39.10969073200479],
#  [-94.58331560930729, 39.098434992563796],
#  [-94.58395354968071, 39.090329915876104],
#  [-94.5838569227594, 39.108077020791995],
#  [-94.5833927965828, 39.094305191424496],
#  [-94.5834831003817, 39.0928864820988],
#  [-94.583414400917, 39.0937800161473],
#  [-94.5838570744198, 39.108076190530504],
#  [-94.5834216131497, 39.0935897284627],
#  [-94.5835073458237, 39.0921702757343],
#  [-94.5834209159586, 39.1008762419165],
#  [-94.58401531059391, 39.0903311926505],
#  [-94.58349646098291, 39.095481055353495],
#  [-94.5834304890531, 39.1008779258331],
#  [-94.583348827542, 39.1008756523459],
#  [-94.5834855350911, 39.0925319238765],
#  [-94.58361468660209, 39.0900776606694],
#  [-94.58385843098308, 39.108077060238706],
#  [-94.5833460711305, 39.098004846205605],
#  [-94.5836357966436, 39.089591756161],
#  [-94.58353959226558, 39.0913591176067],
#  [-94.5835891281336, 39.0936365522125],
#  [-94.5833856469981, 39.097429632984706],
#  [-94.58340863057741, 39.0942180009687],
#  [-94.583478692025, 39.092814049419395],
#  [-94.5835477785304, 39.09119944471],
#  [-94.5830659315674, 39.1082316241456],
#  [-94.58360719173001, 39.0933092903186],
#  [-94.5835369016304, 39.0914267635468],
#  [-94.58350593703491, 39.09535226788039],
#  [-94.5838613944623, 39.10807558049],
#  [-94.58338395051891, 39.097429528887204],
#  [-94.58349739476749, 39.0954674959379],
#  [-94.5833408559054, 39.0979505550781],
#  [-94.58401523004, 39.0903359623909],
#  [-94.5836100954599, 39.0932960471958],
#  [-94.58355769863708, 39.0912574182472],
#  [-94.583853019503, 39.1097040510792],
#  [-94.58360132761459, 39.0902214521078],
#  [-94.5838580176688, 39.1080769084995],
#  [-94.5834792980066, 39.0929756275099],
#  [-94.5838575927318, 39.1080770337032],
#  [-94.5836171935053, 39.0898699578379],
#  [-94.58347258582809, 39.0929484104034],
#  [-94.58337135905529, 39.0976022164986],
#  [-94.5838577645487, 39.1080770788796],
#  [-94.58366988303172, 39.0919560429622],
#  [-94.58347948769439, 39.092811027977795],
#  [-94.5833222750885, 39.0984164780909],
#  [-94.58362733774901, 39.092991780190104],
#  [-94.58346898130009, 39.1008788247667],
#  [-94.5835780423828, 39.09393530908721],
#  [-94.5833970100705, 39.094305870111796],
#  [-94.58355469290241, 39.109769081066204],
#  [-94.58363987592008, 39.092346321713705],
#  [-94.5833325405635, 39.097974310644204],
#  [-94.58355354390021, 39.0911980281689],
#  [-94.58364853426649, 39.0923639045696],
#  [-94.5834836385361, 39.0927453988881],
#  [-94.5835367489914, 39.0914822433453],
#  [-94.5834935582531, 39.1097732781504],
#  [-94.5833701589181, 39.09755828102921],
#  [-94.5836440908143, 39.0924867335436],
#  [-94.58342765631521, 39.1008819426819],
#  [-94.5836606450561, 39.092076008880504],
#  [-94.58333436898519, 39.0981507689982],
#  [-94.5833774142669, 39.097558103824795],
#  [-94.58347950468149, 39.092740670471],
#  [-94.58401589958159, 39.090331654337795],
#  [-94.583316937959, 39.0983752303097],
#  [-94.58359054170609, 39.0936247430566],
#  [-94.58340556064371, 39.0942123613173],
#  [-94.58333953805149, 39.097974658827],
#  [-94.5842039801625, 39.090336387212794],
#  [-94.5838575026852, 39.1080766957177],
#  [-94.5838567377487, 39.1080775747808],
#  [-94.5836431853957, 39.0925734243599],
#  [-94.5838580773612, 39.1080772376113],
#  [-94.584202103076, 39.090336463791296],
#  [-94.58408568550621, 39.0903288624288],
#  [-94.5839185354541, 39.109693764690704],
#  [-94.5838568930558, 39.1080771993844],
#  [-94.5833812164101, 39.0974353380054],
#  [-94.58330578849859, 39.1008744286383],
#  [-94.58334642987171, 39.0979389502096],
#  [-94.58401065163031, 39.09032926936779],
#  [-94.58348914262041, 39.095553509748605],
#  [-94.5834657166531, 39.093245961097004],
#  [-94.58377628209949, 39.1097219874925],
#  [-94.5835154551532, 39.0920527797813],
#  [-94.58385750995122, 39.108076823043206],
#  [-94.58362082486299, 39.0930006055634],
#  [-94.5833550989779, 39.1008767383508],
#  [-94.5833068843844, 39.100872792337796],
#  [-94.5834718501758, 39.092946451001396],
#  [-94.5836613375091, 39.0920917109709],
#  [-94.58351508263658, 39.0953030727494],
#  [-94.5833495068266, 39.0979658453827],
#  [-94.58362452798809, 39.1081219666447],
#  [-94.5835804347814, 39.0937800108413],
#  [-94.5807499378285, 39.1094825602005],
#  [-94.5835295500976, 39.0916124584568],
#  [-94.5836233855221, 39.089860236270006],
#  [-94.58332501178221, 39.0983105717796],
#  [-94.58337158484171, 39.097494752603204],
#  [-94.5834426781348, 39.100882308783895],
#  [-94.5836468023191, 39.0925648116458],
#  [-94.58366533418541, 39.092026884144104],
#  [-94.583335474335, 39.0981382147533],
#  [-94.5834867977011, 39.0925393124044],
#  [-94.5838874362372, 39.090326528161],
#  [-94.583949623228, 39.0903273590865],
#  [-94.5834925649942, 39.109783449446],
#  [-94.58360667202759, 39.093312838707796],
#  [-94.5833930614381, 39.0943052605616],
#  [-94.5833696353022, 39.0974927373312],
#  [-94.58355355846192, 39.0913500304466],
#  [-94.5842060902162, 39.090338703468795],
#  [-94.5836438411562, 39.0925724256334],
#  [-94.5839543835433, 39.0903288274468],
#  [-94.58334310004179, 39.097980498801],
#  [-94.5836142141436, 39.0932259542602],
#  [-94.5834855684149, 39.0925911152695],
#  [-94.5833160949398, 39.0984217351933],
#  [-94.5842025509656, 39.090337841160704],
#  [-94.58332418098111, 39.098305758836204],
#  [-94.58365163138741, 39.09256332383121],
#  [-94.5834169161781, 39.0938105017524],
#  [-94.5833257419536, 39.098316384659704],
#  [-94.583577495648, 39.093784276350604],
#  [-94.5836358465446, 39.0895918332678],
#  [-94.5835484153314, 39.0911975828322],
#  [-94.5835530707505, 39.1008859949034],
#  [-94.58337946025691, 39.097460136922],
#  [-94.5836901034557, 39.091478281964605],
#  [-94.5833280790136, 39.0980869996237],
#  [-94.58360872393959, 39.089993133625796],
#  [-94.58351024984421, 39.0950913990442],
#  [-94.58340009685179, 39.0941043336113],
#  [-94.5837718841399, 39.1097266262556],
#  [-94.5842000134535, 39.0903388601393],
#  [-94.58332534848591, 39.098093956311295],
#  [-94.58391409105259, 39.109694553692705],
#  [-94.5833395961715, 39.0979906893594],
#  [-94.58349199373801, 39.0924623710945],
#  [-94.5840068802364, 39.090331693123204],
#  [-94.5839528980185, 39.0903294302131],
#  [-94.58365174112551, 39.0925108519622],
#  [-94.5834059879446, 39.09410549449821],
#  [-94.5836222913402, 39.089703626574995],
#  [-94.5838557160344, 39.1080775816959],
#  [-94.5838573528992, 39.1080771162389],
#  [-94.58350053273399, 39.0954280789458],
#  [-94.58420667650049, 39.0903372320461],
#  [-94.58364836426979, 39.0925560631488],
#  [-94.5836163506341, 39.0899847759545],
#  [-94.5839524863728, 39.0903290433905],
#  [-94.5838588669859, 39.1080772762763],
#  [-94.58385717937469, 39.1080774025623],
#  [-94.58358543021579, 39.093731674261],
#  [-94.5834882184197, 39.0927247581561],
#  [-94.58361743234, 39.089869778840104],
#  [-94.58420710983971, 39.0903369782211],
#  [-94.5833414967471, 39.0979708941883],
#  [-94.58334143921141, 39.098009713600796],
#  [-94.5836192585425, 39.089869188246205],
#  [-94.58333799121219, 39.098031769159796],
#  [-94.5834083460406, 39.1008779816701],
#  [-94.58361694969379, 39.089868928570205],
#  [-94.584077915296, 39.0903363779352],
#  [-94.5830639706019, 39.1082351443181],
#  [-94.5833691357412, 39.0975467601501],
#  [-94.58383481291641, 39.10808779286221],
#  [-94.5835846709243, 39.093728551454],
#  [-94.5836978541403, 39.091504795394705],
#  [-94.583379305323, 39.0974586654495],
#  [-94.58370397459521, 39.0915055323032],
#  [-94.58341969026291, 39.0937824001173],
#  [-94.58340253145309, 39.094199934056],
#  [-94.58348157186519, 39.0928756001991],
#  [-94.58395330125359, 39.0903298355565],
#  [-94.58340316254471, 39.094051555507896],
#  [-94.58385607190701, 39.108077654971204],
#  [-94.58385848727129, 39.1080770640786],
#  [-94.5838564555949, 39.10807732415],
#  [-94.5835080132537, 39.0921758027386],
#  [-94.58348044377671, 39.0929278384582],
#  [-94.5838566623059, 39.1080771926325],
#  [-94.5839533702471, 39.090328990869295],
#  [-94.5836332658168, 39.0928183346486],
#  [-94.5835064077525, 39.095125370698796],
#  [-94.5838569505225, 39.108077491935894],
#  [-94.5836070235106, 39.0901876537423],
#  [-94.5836163530923, 39.08987029401089],
#  [-94.58361367837891, 39.0900502349894],
#  [-94.58332329795799, 39.0981414540081],
#  [-94.5834941103273, 39.0954902866163],
#  [-94.5835156886386, 39.0950368691215],
#  [-94.58347953206359, 39.0928364440944],
#  [-94.5838586073427, 39.1080769545865],
#  [-94.58395430869659, 39.0903284290444],
#  [-94.58385650630129, 39.108077179248795],
#  [-94.58401748035679, 39.090334129648106],
#  [-94.58420406095058, 39.0903373011639],
#  [-94.58334017172741, 39.09795266368371],
#  [-94.583348351684, 39.1008764430072],
#  [-94.5836658949866, 39.0919382649684],
#  [-94.5835473387081, 39.0913366391533],
#  [-94.58392730125, 39.1096890640946],
#  [-94.5834859766226, 39.092770254949606],
#  [-94.58340289445009, 39.094201636143104],
#  [-94.5833708205237, 39.097553616767705],
#  [-94.58420876798029, 39.0903347876653],
#  [-94.5833703762269, 39.0974839220455],
#  [-94.5833237396459, 39.098141110498396],
#  [-94.58348586892392, 39.0925307538782],
#  [-94.5838574649327, 39.1080772161785],
#  [-94.5834023911664, 39.094200754191604],
#  [-94.5833297771282, 39.098181585171],
#  [-94.5830457078577, 39.1082400599276],
#  [-94.5835453716763, 39.09131635979],
#  [-94.5834880164595, 39.1008811491944],
#  [-94.5833123103771, 39.0983796331381],
#  [-94.5837829389517, 39.089630718015],
#  [-94.580794431225, 39.1096094918635],
#  [-94.5836205852495, 39.089743231842604],
#  [-94.58376601703439, 39.1080955463499],
#  [-94.5835420444989, 39.091431347672895],
#  [-94.58345552135071, 39.0932972673571],
#  [-94.5833297949214, 39.098315659962104],
#  [-94.5840079651496, 39.0903352774194],
#  [-94.58361124305661, 39.0901331313234],
#  [-94.5833802536347, 39.097460706683606],
#  [-94.5838802168445, 39.0903245722608],
#  [-94.5834717000469, 39.0929659259769],
#  [-94.58385401259649, 39.1097052100312],
#  [-94.5834782652207, 39.092816704792796],
#  [-94.58346528671508, 39.0932398602146],
#  [-94.583336534375, 39.0980413485342],
#  [-94.5833300420749, 39.098314215063894],
#  [-94.5833432629697, 39.097928755326],
#  [-94.5834000939722, 39.1008771516137],
#  [-94.58349972152071, 39.0924533738258],
#  [-94.58340475364, 39.094076984103204],
#  [-94.58347174817551, 39.0929476672005],
#  [-94.5833800735215, 39.0974373432266],
#  [-94.5833388252984, 39.0979520644015],
#  [-94.58385608598559, 39.10807718632721],
#  [-94.58364853486809, 39.0925548870878],
#  [-94.5833251647441, 39.0981411161079],
#  [-94.58332453740721, 39.098141639095104],
#  [-94.5835072390265, 39.0954883497259],
#  [-94.5836186284311, 39.089869826798896],
#  [-94.5838575296227, 39.1080771858719],
#  [-94.58363611456801, 39.0895862981219],
#  [-94.5834921973619, 39.095413139763],
#  [-94.5839521934235, 39.090329658902796],
#  [-94.5836192339864, 39.0930341728735],
#  [-94.5836228756897, 39.089722824541795],
#  [-94.58350884581341, 39.0921182809918],
#  [-94.58362510726549, 39.0899707137531],
#  [-94.58366138350979, 39.0924378522534],
#  [-94.58334872486309, 39.097966100614],
#  [-94.5834269459894, 39.0936425782417],
#  [-94.58385616219749, 39.1080775491301],
#  [-94.58365601081199, 39.0921812401652],
#  [-94.58077387713091, 39.109540042976704],
#  [-94.5837171015431, 39.1097313640306],
#  [-94.58332710298971, 39.098175935421],
#  [-94.58350885209671, 39.092120894174],
#  [-94.58420125906109, 39.090337879233],
#  [-94.5841366886828, 39.0903353811605],
#  [-94.5838570401625, 39.1080761620708],
#  [-94.5842050518865, 39.0903377499764],
#  [-94.58385703468271, 39.108078148157794],
#  [-94.58333407651091, 39.0980854095384],
#  [-94.5833160771907, 39.098375641302795],
#  [-94.58346487276121, 39.0932378131891],
#  [-94.5836296113697, 39.0928547743375],
#  [-94.58339643800508, 39.09416472942429],
#  [-94.5841966067058, 39.090338810562294],
#  [-94.5836112835664, 39.0901354561247],
#  [-94.5836209680642, 39.08997927410471],
#  [-94.5836900714111, 39.0914237139265],
#  [-94.5841503661373, 39.0903328999251],
#  [-94.5835101145928, 39.0950927726541],
#  [-94.5833686840802, 39.0975561578274],
#  [-94.5836442506647, 39.0925761392825],
#  [-94.58341346608678, 39.094327526099704],
#  [-94.5836184017658, 39.0898701865716],
#  [-94.58349383052021, 39.1008856081631],
#  [-94.58347328072658, 39.092948908758295],
#  [-94.58361998852992, 39.0928023365035],
#  [-94.5833407147946, 39.098027620774396],
#  [-94.583857505443, 39.108077292340106],
#  [-94.5838565321693, 39.108077922963],
#  [-94.58385722895781, 39.10807733315271],
#  [-94.5838596048897, 39.108075179614794],
#  [-94.58385831745008, 39.1080773756317],
#  [-94.5833661354754, 39.097533357511],
#  [-94.5834183614859, 39.09380118762321],
#  [-94.58333461437469, 39.0980751223561],
#  [-94.5834861600741, 39.0927248926334],
#  [-94.58377429473259, 39.1097229423905],
#  [-94.5836192854303, 39.0898706840281],
#  [-94.58402712389471, 39.090331580063705],
#  [-94.5836538614266, 39.09217323137629],
#  [-94.58362555397491, 39.1081239822351],
#  [-94.5804999756093, 39.1091116449937],
#  [-94.58361938571998, 39.0898695442822],
#  [-94.58385837161998, 39.1080770364693],
#  [-94.58362612460822, 39.089952798616096],
#  [-94.5833436910647, 39.09796415680079],
#  [-94.5833739491993, 39.0976028186215],
#  [-94.5835871887484, 39.0936484829558],
#  [-94.58342837159609, 39.1008806902224],
#  [-94.5836598810837, 39.0920766208995],
#  [-94.58369117243, 39.109745373696605],
#  [-94.5834842984744, 39.092594130036396],
#  [-94.5834821036712, 39.0928783343799],
#  [-94.5838567744496, 39.1080771529538],
#  [-94.5841498557028, 39.0903341448057],
#  [-94.5841479669208, 39.0903343996529],
#  [-94.5835571502668, 39.091100786687996],
#  [-94.5835815821614, 39.0939494911347],
#  [-94.58348398185271, 39.0928822925621],
#  [-94.58385624742719, 39.1080772887236],
#  [-94.58340563056959, 39.0941033310773],
#  [-94.5836083351322, 39.0901862695479],
#  [-94.58383769584559, 39.0888615008555],
#  [-94.58383485164042, 39.0888878793969],
#  [-94.5838282187695, 39.0889265395115],
#  [-94.58385141673759, 39.1097036199319],
#  [-94.5841514558786, 39.090333659675395],
#  [-94.58350716064258, 39.09218725048721],
#  [-94.58355824292879, 39.0911031780855],
#  [-94.58395272572781, 39.090329559295704],
#  [-94.5829590332872, 39.1040113398009],
#  [-94.58385716592319, 39.1080774326971],
#  [-94.5836848107798, 39.1081095774109],
#  [-94.5838582732696, 39.108077476207],
#  [-94.5833313497754, 39.0982648807171],
#  [-94.58332502663191, 39.0981397607616],
#  [-94.58361774594059, 39.089871418708704],
#  [-94.5836193885419, 39.0898676870943],
#  [-94.5836196542725, 39.0898706157532],
#  [-94.5835849858862, 39.093955931044],
#  [-94.5833398408996, 39.0980190282731],
#  [-94.58351238618549, 39.095109537272],
#  [-94.5836263176857, 39.0928501583765],
#  [-94.5834035222567, 39.0941986614337],
#  [-94.5834030257525, 39.0941991767158],
#  [-94.58340319032429, 39.0941985743965],
#  [-94.5837708141448, 39.109722903545105],
#  [-94.5834028180233, 39.094199363521],
#  [-94.58385649618099, 39.108076371579706],
#  [-94.5824422725814, 39.1083605271661],
#  [-94.58350885757841, 39.095113322203005],
#  [-94.5834021988372, 39.094200137286],
#  [-94.583509236258, 39.0951166177775],
#  [-94.5840586251117, 39.0903350104061],
#  [-94.58241538738591, 39.1083671592934],
#  [-94.58385693336491, 39.1080776280149],
#  [-94.5834184708182, 39.0938347201824],
#  [-94.5834021079914, 39.0942009996],
#  [-94.58349325660879, 39.0954123557672],
#  [-94.583403139792, 39.094199076655606],
#  [-94.58340326610072, 39.0941986246671],
#  [-94.5838421811115, 39.0888725858555],
#  [-94.5836107092765, 39.0901335870576],
#  [-94.58350436930279, 39.0952053712919],
#  [-94.58350816279051, 39.0951155605149],
#  [-94.58368365330999, 39.1081086854184],
#  [-94.58351231841101, 39.0951126252356],
#  [-94.583088396571, 39.1098695343206],
#  [-94.58351870309151, 39.0922478448764],
#  [-94.5834820793688, 39.109787845808],
#  [-94.5830713992869, 39.108232047042996],
#  [-94.58361822969731, 39.089869040234795],
#  [-94.5834035287496, 39.0941990471736],
#  [-94.5834037854348, 39.0941989536078],
#  [-94.5835765852794, 39.1008915352769],
#  [-94.58357085509441, 39.1008850196728],
#  [-94.5834043947879, 39.0941980011641],
#  [-94.5834246831019, 39.093658603091605],
#  [-94.5835081344663, 39.0921222535741],
#  [-94.583953621496, 39.0903300679035],
#  [-94.58400501277309, 39.0903299449372],
#  [-94.58350937776, 39.0950922994475],
#  [-94.5834056281495, 39.1008743778008],
#  [-94.5833373223358, 39.0980280083696],
#  [-94.58385755876259, 39.108077810017704],
#  [-94.58348088861841, 39.0928967251703],
#  [-94.5834736152233, 39.092951639917494],
#  [-94.5834849551277, 39.0927606496211],
#  [-94.58346481009269, 39.093235235418796],
#  [-94.5836216408399, 39.0899276507654],
#  [-94.58385870201741, 39.108076733437706],
#  [-94.58361278763941, 39.090052730824205],
#  [-94.58420745913341, 39.0903373650673],
#  [-94.5836278742952, 39.0930048484719],
#  [-94.5836202403271, 39.0897224200725],
#  [-94.583613508081, 39.089927747005],
#  [-94.58385778905908, 39.108077077754295],
#  [-94.58420483560829, 39.090336204638206],
#  [-94.58333197668242, 39.0982733395616],
#  [-94.5834054448288, 39.0942140899828],
#  [-94.5838569894533, 39.1080778801231],
#  [-94.58334401838671, 39.097931604039104],
#  [-94.58385673039172, 39.108077531820605],
#  [-94.58378365373291, 39.10971726707],
#  [-94.5836893449012, 39.0914609353242],
#  [-94.5830305472575, 39.108242815572794],
#  [-94.58334315409391, 39.0979512198314],
#  [-94.5835014117854, 39.095163786971895],
#  [-94.5834995112108, 39.0954063096665],
#  [-94.5841997161832, 39.0903381072032],
#  [-94.58385946429381, 39.1080759452171],
#  [-94.5838569841844, 39.1080773306185],
#  [-94.583892936803, 39.0903239378176],
#  [-94.5839517227271, 39.090329860704706],
#  [-94.58392866557591, 39.1096891922275],
#  [-94.5834978516281, 39.0954698262178],
#  [-94.5838571853962, 39.1080772380923],
#  [-94.58362889848179, 39.0895871320026],
#  [-94.58351679137449, 39.0950352540461],
#  [-94.58347832787778, 39.092813382981795],
#  [-94.58336721118259, 39.0975573229787],
#  [-94.58395284712499, 39.090328922254],
#  [-94.5835263108799, 39.0916104084768],
#  [-94.5834855023296, 39.0927408105879],
#  [-94.5833738090748, 39.1008849438976],
#  [-94.5838562027505, 39.1080773941009],
#  [-94.5831934260469, 39.109852024751],
#  [-94.58332652200991, 39.0983102490756],
#  [-94.58383793312359, 39.0888973316495],
#  [-94.58077091487351, 39.109519459302504],
#  [-94.5833693748338, 39.0975481725105],
#  [-94.5835155749168, 39.095160618740294],
#  [-94.58385670561809, 39.1080758448051],
#  [-94.58361054241828, 39.093277524082204],
#  [-94.5835160296608, 39.095154788741105],
#  [-94.58349202981822, 39.1097870097225],
#  [-94.5836188866634, 39.0898698717875],
#  [-94.58340411228541, 39.09419876800521],
#  [-94.58053773243358, 39.1092149871382],
#  [-94.5833832900268, 39.0974353784486],
#  [-94.58340465266359, 39.0941976403532],
#  [-94.58342330927499, 39.093650488540604],
#  [-94.58350487769991, 39.095366089559704],
#  [-94.5807534085757, 39.1094643056708],
#  [-94.5834873553752, 39.092569919761296],
#  [-94.58363318412322, 39.089539252533896],
#  [-94.58385511475441, 39.108075887095104],
#  [-94.5837780907112, 39.1097213976824],
#  [-94.58357392827259, 39.0939441668767],
#  [-94.583574060424, 39.093959941446],
#  [-94.5833925736286, 39.094305249654106],
#  [-94.58415036565229, 39.090332901222204],
#  [-94.5842095948047, 39.090337875934296],
#  [-94.5833438618355, 39.100869277507],
#  [-94.58385871838249, 39.1080769892484],
#  [-94.58350527413891, 39.0954938112604],
#  [-94.5834825845772, 39.092594831191796],
#  [-94.5836167553331, 39.093075770678894],
#  [-94.5842026984929, 39.0903376172537],
#  [-94.58385730050449, 39.1080768617855],
#  [-94.5807613431393, 39.1095421255322],
#  [-94.58366048027919, 39.0920894505592],
#  [-94.58385825456008, 39.1080761739684],
#  [-94.58385711245892, 39.10807720453],
#  [-94.58333969348291, 39.0979527886814],
#  [-94.58349031469679, 39.0924794537771],
#  [-94.5834798954685, 39.092893238734604],
#  [-94.5838596254653, 39.108076343867396],
#  [-94.5833413141078, 39.097948237551705],
#  [-94.5834127274201, 39.0938666104604],
#  [-94.5842033757617, 39.0903376370029],
#  [-94.58362805206129, 39.089521382135295],
#  [-94.58350414318019, 39.0922326541435],
#  [-94.5836140032753, 39.0930115750758],
#  [-94.58385858772628, 39.1080773791709],
#  [-94.5836238130691, 39.0897235693944],
#  [-94.58333894485679, 39.0980682012539],
#  [-94.5836173566949, 39.089869375008604],
#  [-94.583407053188, 39.1008779052077],
#  [-94.5833673241915, 39.0974951970749],
#  [-94.58363575247459, 39.08958916739579],
#  [-94.5836397096205, 39.0895257458864],
#  [-94.5838581235594, 39.1080771710364],
#  [-94.5836198542181, 39.0898699144127],
#  [-94.5834885704302, 39.0927440996869],
#  [-94.5836592820293, 39.0924394843104],
#  [-94.58385768040091, 39.1080778382798],
#  [-94.58354260963041, 39.0913670605349],
#  [-94.5836262108468, 39.0928545683758],
#  [-94.58340379342691, 39.0941987161712],
#  [-94.58340284533979, 39.0942002137742],
#  [-94.5835099681522, 39.0951118803],
#  [-94.58361572144871, 39.0899533331065],
#  [-94.58090337509991, 39.109878359704],
#  [-94.5837862812722, 39.089629789572],
#  [-94.5834027381792, 39.0941993813888],
#  [-94.58357904975729, 39.1008831548012],
#  [-94.583636019539, 39.0895909054261],
#  [-94.583430114732, 39.0935843485089],
#  [-94.5838606961743, 39.1080759865623],
#  [-94.58340322933691, 39.094199847482706],
#  [-94.5836246658949, 39.0899250106944],
#  [-94.5808960040168, 39.1098679159904],
#  [-94.58091253797751, 39.109923537060205],
#  [-94.58346307753142, 39.0932409919966],
#  [-94.5835081744978, 39.0951142522086],
#  [-94.5833264005002, 39.098303359326],
#  [-94.5837868165443, 39.0896721985031],
#  [-94.5833830005757, 39.0974348192359],
#  [-94.5831820027832, 39.1098601369769],
#  [-94.58358710195999, 39.0936465059094],
#  [-94.583508637179, 39.095115352148],
#  [-94.5833309369491, 39.0981881488536],
#  [-94.5835108242931, 39.0921211642367],
#  [-94.5836252105167, 39.08969259280921],
#  [-94.58369793318809, 39.0914504541606],
#  [-94.58344688522791, 39.100881349569896],
#  [-94.5830780654472, 39.1098724506594],
#  [-94.5835060776548, 39.092231584158],
#  [-94.5835062521101, 39.092231339247704],
#  [-94.5832461796208, 39.1098474403989],
#  [-94.5835056752478, 39.092232388075296],
#  [-94.58335676487239, 39.1008786818839],
#  [-94.58385753368981, 39.108077560031205],
#  [-94.5833191257694, 39.0984161137218],
#  [-94.5835021601381, 39.0954048803816],
#  [-94.5834884495238, 39.0955754095382],
#  [-94.5836099128833, 39.090132050348295],
#  [-94.58385601580481, 39.108077467771295],
#  [-94.58333521805349, 39.0980377009815],
#  [-94.58342310146169, 39.0935818182025],
#  [-94.58347888788879, 39.09289404577861],
#  [-94.5836613413011, 39.092090222219795],
#  [-94.5834844345804, 39.092548656889896],
#  [-94.5836569755194, 39.0922542157495],
#  [-94.58364889950279, 39.092363178704],
#  [-94.58340345875419, 39.0938858368481],
#  [-94.58334491097891, 39.0979425039989],
#  [-94.583426117608, 39.0935939627795],
#  [-94.5838575914445, 39.1080775055945],
#  [-94.5833318665057, 39.0982718922861],
#  [-94.58342690708392, 39.1008794500235],
#  [-94.58340075154508, 39.094098418209995],
#  [-94.583478215902, 39.0927602869589],
#  [-94.5833314977214, 39.098191603214296],
#  [-94.58348713520469, 39.09253215681179],
#  [-94.58350531186241, 39.09526732654871],
#  [-94.5835446424927, 39.0913730429437],
#  [-94.58333469194152, 39.0981874389324],
#  [-94.58378482128981, 39.0896297164167],
#  [-94.5838603389152, 39.1080758149452],
#  [-94.5833773562356, 39.0975895997637],
#  [-94.58385770662859, 39.108077723015],
#  [-94.58383702201851, 39.0889220895902],
#  [-94.5834767226778, 39.09295145306071],
#  [-94.58349329456041, 39.109788718179004],
#  [-94.58340405539239, 39.0941982877889],
#  [-94.58361065502109, 39.090133349157],
#  [-94.58420450535691, 39.090336697764],
#  [-94.58339923103641, 39.0942738529936],
#  [-94.58356001583141, 39.091282976754705],
#  [-94.58368431142401, 39.1081095291291],
#  [-94.58385672500009, 39.108077432705706],
#  [-94.5832430322279, 39.109845838445004],
#  [-94.58361454077591, 39.0899902430479],
#  [-94.583634774087, 39.0895102360251],
#  [-94.5833301867466, 39.098188697353],
#  [-94.5835406176338, 39.091310837533],
#  [-94.58347994238791, 39.0927732760648],
#  [-94.58385763147791, 39.1080768052355],
#  [-94.5838568589089, 39.108077096154794],
#  [-94.5842048664233, 39.0903362432324],
#  [-94.58361527634621, 39.0901195050997],
#  [-94.58349122773251, 39.0924736420253],
#  [-94.58348927308408, 39.092473142066105],
#  [-94.5838604270998, 39.1080759856517],
#  [-94.5836239605316, 39.0897426571397],
#  [-94.583628929706, 39.0930052888464],
#  [-94.5835463294916, 39.0910921312703],
#  [-94.58363381777849, 39.089509763775894],
#  [-94.5834012633611, 39.0940661284991],
#  [-94.5838559192557, 39.1080776453587],
#  [-94.5834848648349, 39.0925921557385],
#  [-94.5834230275228, 39.100879965214794],
#  [-94.5836270943288, 39.092817006463704],
#  [-94.58364941057779, 39.092333034108],
#  [-94.5836219919214, 39.0899277164299],
#  [-94.5836253136173, 39.089646630960296],
#  [-94.5842086991082, 39.090337590701],
#  [-94.58348175198891, 39.0928762185481],
#  [-94.5835844620941, 39.093713316184],
#  [-94.58347195412729, 39.09294561559],
#  [-94.58342284959558, 39.100876951132896],
#  [-94.5835043301021, 39.0953550497579],
#  [-94.5833263947786, 39.0983104119846],
#  [-94.58351000762859, 39.0951160507818],
#  [-94.5835113233416, 39.092104115181705],
#  [-94.58348928130779, 39.1097899030823],
#  [-94.58350904060708, 39.0951180952273],
#  [-94.58351557387459, 39.092043486162794],
#  [-94.58351086546999, 39.0951117643478],
#  [-94.5833378841333, 39.0981166040268],
#  [-94.58351128045109, 39.0951117796042],
#  [-94.5835087390061, 39.095116460316895],
#  [-94.58364575488591, 39.0924411733578],
#  [-94.5824163850066, 39.108369127500204],
#  [-94.5833353608951, 39.098065469309],
#  [-94.5837292372027, 39.1097346987343],
#  [-94.5833945041091, 39.09425273235679],
#  [-94.58357674039179, 39.0939611326901],
#  [-94.58351082208021, 39.095114640285004],
#  [-94.5805314235537, 39.1092027499068],
#  [-94.58353911543041, 39.1008943781774],
#  [-94.5835068815979, 39.092231450697604],
#  [-94.58377964264099, 39.089663378938106],
#  [-94.5830602595361, 39.1082358566541],
#  [-94.58363647683778, 39.0895182469734],
#  [-94.58355880102371, 39.1008860096122],
#  [-94.5839545614778, 39.0903283720519],
#  [-94.5838587650107, 39.1080763124698],
#  [-94.58362751994959, 39.0895855115396],
#  [-94.5840340190271, 39.0903288166788],
#  [-94.5838570486634, 39.1080760602757],
#  [-94.58332609134621, 39.09819513588],
#  [-94.5833440859162, 39.100875278426706],
#  [-94.5837023655411, 39.0914218455299],
#  [-94.58339062838259, 39.0941652309103],
#  [-94.5835691390915, 39.0910723076605],
#  [-94.583619642387, 39.0898697208962],
#  [-94.58349508030929, 39.0928774283066],
#  [-94.5834812543667, 39.0928888968226],
#  [-94.5833225635092, 39.0981424904569],
#  [-94.58340517602699, 39.0942107455116],
#  [-94.5833398269759, 39.097970218216],
#  [-94.58333764651579, 39.0980699881778],
#  [-94.58361965420359, 39.0898699733854],
#  [-94.58333093849251, 39.098268569208],
#  [-94.5834937098068, 39.0927397770598],
#  [-94.583857073076, 39.108077147344396],
#  [-94.5836212413015, 39.0898686781695],
#  [-94.5838572139627, 39.108077297906604],
#  [-94.5834483650204, 39.1008812212843],
#  [-94.5834945853442, 39.095491805832204],
#  [-94.5834025157999, 39.094210437754604],
#  [-94.5838565589731, 39.1080769482555],
#  [-94.5834914080815, 39.095509431853706],
#  [-94.58362886992902, 39.109753157248996],
#  [-94.5836485315878, 39.0922747003173],
#  [-94.5835118146439, 39.0951120431209],
#  [-94.58354331897499, 39.0913794891959],
#  [-94.5838370129798, 39.0889085867552],
#  [-94.5835095758472, 39.0951166726353],
#  [-94.5836324862151, 39.0896850873504],
#  [-94.5836083791582, 39.090078727244894],
#  [-94.58361502087601, 39.090043804181704],
#  [-94.5835139094143, 39.095111980806706],
#  [-94.5835121670978, 39.095114271519606],
#  [-94.58332732186578, 39.098289344392796],
#  [-94.5835811705486, 39.0937737840403],
#  [-94.583512766054, 39.092099460053795],
#  [-94.58404208869021, 39.090330441484106],
#  [-94.58049785766859, 39.109097848915404],
#  [-94.5833749055669, 39.10087406640179],
#  [-94.5835130015357, 39.0951130862611],
#  [-94.58075159439942, 39.1094736794086],
#  [-94.58079435256491, 39.109609642468705],
#  [-94.5836263269123, 39.0928541491163],
#  [-94.58342902851, 39.0937876373811],
#  [-94.58340364976699, 39.0941990684776],
#  [-94.5838390359162, 39.088902932340396],
#  [-94.58362089784781, 39.0899686380884],
#  [-94.5836184928459, 39.089869810855205],
#  [-94.58350861550609, 39.0951141723701],
#  [-94.5838577553311, 39.1080778053875],
#  [-94.5835094626104, 39.09511643928779],
#  [-94.5839278564364, 39.1096894811537],
#  [-94.58319713025939, 39.1082096955604],
#  [-94.5834036789576, 39.0941985146937],
#  [-94.58339737625559, 39.0943472893363],
#  [-94.5834032580534, 39.0941981313418],
#  [-94.58340349469759, 39.09419917662979],
#  [-94.5834026752012, 39.09419950259829],
#  [-94.58363474156928, 39.0895211262465],
#  [-94.5835022256528, 39.0924583065573],
#  [-94.583509101635, 39.0951137500354],
#  [-94.5836165402374, 39.0898718204957],
#  [-94.5836260707093, 39.0929749937765],
#  [-94.5832981551433, 39.1008727532776],
#  [-94.5841140951693, 39.090335588224],
#  [-94.583403305444, 39.094200662361004],
#  [-94.5836151597273, 39.093042087583],
#  [-94.5833415602911, 39.0979644711979],
#  [-94.5836349144866, 39.0895859567421],
#  [-94.583922646691, 39.109691011550396],
#  [-94.5833402988043, 39.0979696225117],
#  [-94.5833715767325, 39.100869953745296],
#  [-94.5836589909602, 39.0920877672328],
#  [-94.5838577760376, 39.108077150746105],
#  [-94.5836194041807, 39.0898698075071],
#  [-94.5833491091807, 39.097962593255296],
#  [-94.5834184348332, 39.0936282089624],
#  [-94.58350216708159, 39.0922234850032],
#  [-94.58361859669321, 39.0898699128235],
#  [-94.58395214847141, 39.0903298168489],
#  [-94.5838579196932, 39.1080765931151],
#  [-94.583370479612, 39.1008801082199],
#  ...]

# %%
cdf.loc[(cdf['asset_id']=='SENSITY-kc-1') & (cdf['start_time']=='2018-11-03 13:30:00')].\
apply(lambda y: list([y['longitude'],y['latitude']]),axis=1).tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-544-38d001f2cd01> in <module>
#       1 cdf.loc[(cdf['asset_id']=='SENSITY-kc-1') & (cdf['start_time']=='2018-11-03 13:30:00')].\
# ----> 2 apply(lambda y: list([y['longitude'],y['latitude']]),axis=1).tolist()
#
# ~/anaconda3/envs/work/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'tolist'

# %%
cdf['start_time'] = pd.to_datetime(cdf.start_time,format='%Y/%m/%d').astype('datetime64[s]')
cdf['end_time'] = pd.to_datetime(cdf.end_time,format='%Y/%m/%d').astype('datetime64[s]')

# %%
cdf.loc[(cdf['asset_id']=='SENSITY-kc-1') &(cdf['start_from_fc']=='2018-11-03 13:30:00')]
# Out:
#                                                      uuid      asset_id  \
# 121802  SENSITY-kc-1-8FC6AB26-2AC4-49C6-B3CE-69C756A461DD  SENSITY-kc-1
#
#                 start_time            end_time session_type   latitude  \
# 121802 2018-11-03 13:30:59 2018-11-03 17:13:46          car  39.088894
#
#         longitude                                           geometry  \
# 121802 -94.583837  {"type":"Polygon","coordinates":[[[-94.5838458...
#
#              start_from_fc         end_from_fc
# 121802 2018-11-03 13:30:00 2018-11-03 17:15:00

# %%
cdf['start_from_fc']= cdf.start_time.dt.floor('5min')
cdf['end_from_fc'] = cdf.end_time.dt.ceil('5min')

# %%
cdf
# Out:
#                                                      uuid       asset_id  \
# 0       SENSITY-kc-23-40D98DC1-41F8-40EE-BBB8-E44DE41C...  SENSITY-kc-23
# 1       SENSITY-kc-22-E5EBBB3A-05E4-4D9C-97CB-26542918...  SENSITY-kc-22
# 2       SENSITY-kc-10-C4D472BA-65CA-4D2B-A6C0-9C3981CD...  SENSITY-kc-10
# 3       SENSITY-kc-12-4C26D1EC-4CCE-4E9A-87D1-D93149F5...  SENSITY-kc-12
# 4       SENSITY-kc-9-CDDB22AD-31F6-4A11-BC94-CCC6602575A1   SENSITY-kc-9
# 5       SENSITY-kc-14-EC9EB215-CFAC-437F-9FEE-CF8917FF...  SENSITY-kc-14
# 6       SENSITY-kc-18-B6079A6A-B9EF-4080-B4D8-B2BA7099...  SENSITY-kc-18
# 7       SENSITY-kc-2-2EB5BA3B-6629-4298-9D02-D292CE41641E   SENSITY-kc-2
# 8       SENSITY-kc-12-012FEE39-6092-419F-B096-31FA7A37...  SENSITY-kc-12
# 9       SENSITY-kc-21-8A06DAEC-A8E9-4996-8723-51570636...  SENSITY-kc-21
# 10      SENSITY-kc-21-4A7750BE-5AA9-492D-B913-04ED44E5...  SENSITY-kc-21
# 11      SENSITY-kc-8-A0436C6D-91A9-452B-8561-A1F44BF0C381   SENSITY-kc-8
# 12      SENSITY-kc-9-04B89F44-D078-4E0D-8395-648BF0D779BB   SENSITY-kc-9
# 13      SENSITY-kc-10-8273AE52-1D5F-4C86-820A-067FBE1F...  SENSITY-kc-10
# 14      SENSITY-kc-8-936405B7-7462-46FD-B10E-09D22F407139   SENSITY-kc-8
# 15      SENSITY-kc-8-1FE9FA74-7FC8-4721-BFD9-17A05014900E   SENSITY-kc-8
# 16      SENSITY-kc-12-67CD92D1-1144-45D6-8938-12830A09...  SENSITY-kc-12
# 17      SENSITY-kc-14-7B69BC78-1676-4132-A4DB-A0C4874B...  SENSITY-kc-14
# 18      SENSITY-kc-12-1A22267D-E0F1-4CBF-99B7-AE3AFA38...  SENSITY-kc-12
# 19      SENSITY-kc-14-49219653-B436-4ECF-87B2-CEDE9349...  SENSITY-kc-14
# 20      SENSITY-kc-2-8FABCBD4-9024-4C48-9D88-2595443C86E8   SENSITY-kc-2
# 21      SENSITY-kc-10-E84971B1-043E-4F45-9AEC-358240DD...  SENSITY-kc-10
# 22      SENSITY-kc-9-E23BD89B-8118-4445-9FCC-772DA5DB7E15   SENSITY-kc-9
# 23      SENSITY-kc-15-C71272E1-BD6E-4F68-83EB-18873CD7...  SENSITY-kc-15
# 24      SENSITY-kc-10-463011E6-0068-464D-96FC-2800CEB4...  SENSITY-kc-10
# 25      SENSITY-kc-23-66466105-BEA6-408A-8900-FDA4737C...  SENSITY-kc-23
# 26      SENSITY-kc-14-D909FA91-A122-4289-928C-79CE91BC...  SENSITY-kc-14
# 27      SENSITY-kc-10-0B3CB4D5-CDE5-4CCC-90B8-B5D802F8...  SENSITY-kc-10
# 28      SENSITY-kc-10-DD5A7279-56BC-4771-BB59-DB591329...  SENSITY-kc-10
# 29      SENSITY-kc-18-7F80957D-A9CA-407C-80FC-5913F6B6...  SENSITY-kc-18
# ...                                                   ...            ...
# 162094  SENSITY-kc-10-2F7882A5-C7C0-4AB8-A515-1177B625...  SENSITY-kc-10
# 162095  SENSITY-kc-12-8FF5C8FE-B542-49CF-88E9-BC00A01B...  SENSITY-kc-12
# 162096  SENSITY-kc-9-138FED19-AE19-412D-95A6-B41D5B6FF4ED   SENSITY-kc-9
# 162097  SENSITY-kc-8-6CED1DB5-1AAC-40AB-8ABE-96ABFFA510B3   SENSITY-kc-8
# 162098  SENSITY-kc-9-0996161E-466F-4AC2-9A57-8DB5AEFF2BDB   SENSITY-kc-9
# 162099  SENSITY-kc-14-737064A2-2697-4950-A0E3-BF3758B4...  SENSITY-kc-14
# 162100  SENSITY-kc-9-63608323-DA3F-4C86-A099-D9CAE8950D54   SENSITY-kc-9
# 162101  SENSITY-kc-7-1D958CD7-578B-4968-A799-3FA5A34BF6A5   SENSITY-kc-7
# 162102  SENSITY-kc-4-040F09B1-9C75-498E-ADFD-EAC1151CCC77   SENSITY-kc-4
# 162103  SENSITY-kc-10-0C46FB05-47E0-4F7E-8BAE-B5775E99...  SENSITY-kc-10
# 162104  SENSITY-kc-6-E6E0392A-2A48-4BE3-A90D-DBE6D8331609   SENSITY-kc-6
# 162105  SENSITY-kc-19-D7613A2C-5EEB-4969-AC6F-3A0C8C0B...  SENSITY-kc-19
# 162106  SENSITY-kc-2-B0337686-262D-4A70-933F-B6902018F339   SENSITY-kc-2
# 162107  SENSITY-kc-19-43A62096-C768-4751-95B8-2D76E3D7...  SENSITY-kc-19
# 162108  SENSITY-kc-6-73B6DF35-EE94-4DBA-8EDF-7E6EF877BA24   SENSITY-kc-6
# 162109  SENSITY-kc-8-5CDB74F5-2F37-41E8-81B1-1D8F9DBA6F86   SENSITY-kc-8
# 162110  SENSITY-kc-2-550877C2-A6E8-4DF2-89A4-1F53ED51C6DF   SENSITY-kc-2
# 162111  SENSITY-kc-15-33E1D598-BCC3-40FC-952C-CCE804AF...  SENSITY-kc-15
# 162112  SENSITY-kc-2-5D1781B7-C01A-46C8-A681-214FE9FE2FCE   SENSITY-kc-2
# 162113  SENSITY-kc-4-E88AF864-6AFD-4BD1-8630-8982D4949945   SENSITY-kc-4
# 162114  SENSITY-kc-12-137A56F8-18ED-4BFE-A572-F7993CED...  SENSITY-kc-12
# 162115  SENSITY-kc-10-FA464535-7C74-4507-B77E-02907ADB...  SENSITY-kc-10
# 162116  SENSITY-kc-10-7BE3A817-36BF-43CB-B2E7-690DDA59...  SENSITY-kc-10
# 162117  SENSITY-kc-2-D3AE8837-412C-4332-8042-CE4A7FA8DA51   SENSITY-kc-2
# 162118  SENSITY-kc-9-0E393B2D-4AC4-4236-BFB7-430E80A89639   SENSITY-kc-9
# 162119  SENSITY-kc-2-571F432D-B01E-4D91-8706-3C4BB35308A1   SENSITY-kc-2
# 162120  SENSITY-kc-15-062F1B04-4662-417E-A716-B00B3B7D...  SENSITY-kc-15
# 162121  SENSITY-kc-12-A51124BE-1F0D-4A17-A26F-765EE187...  SENSITY-kc-12
# 162122  SENSITY-kc-12-2097DFAB-0459-42BE-B7C0-789D5346...  SENSITY-kc-12
# 162123  SENSITY-kc-6-547614AC-6FEB-4DB3-9466-B27AEEA2A0CF   SENSITY-kc-6
#
#                 start_time            end_time session_type   latitude  \
# 0      2018-08-10 23:33:26 2018-08-10 23:33:55          car  39.109786
# 1      2018-08-10 23:34:58 2018-08-10 23:36:08          car  39.109536
# 2      2018-08-10 23:33:40 2018-08-10 23:36:25          car  39.094360
# 3      2018-08-10 23:34:44 2018-08-10 23:38:53          car  39.095302
# 4      2018-08-10 23:37:38 2018-08-10 23:39:01          car  39.092984
# 5      2018-08-10 23:34:12 2018-08-10 23:39:38          car  39.097486
# 6      2018-08-10 23:36:28 2018-08-10 23:40:19          car  39.108123
# 7      2018-08-10 23:33:24 2018-08-10 23:47:47          car  39.089526
# 8      2018-08-10 23:47:25 2018-08-10 23:47:50          car  39.095549
# 9      2018-08-10 23:47:51 2018-08-10 23:49:26          car  39.109129
# 10     2018-08-10 23:49:23 2018-08-10 23:51:11          car  39.109096
# 11     2018-08-10 23:45:06 2018-08-10 23:54:05          car  39.092873
# 12     2018-08-10 23:50:59 2018-08-10 23:54:44          car  39.092272
# 13     2018-08-10 23:48:31 2018-08-10 23:55:04          car  39.094211
# 14     2018-08-10 23:54:05 2018-08-10 23:56:43          car  39.092193
# 15     2018-08-10 23:57:21 2018-08-10 23:58:20          car  39.092119
# 16     2018-08-10 23:55:31 2018-08-11 00:03:00          car  39.095554
# 17     2018-08-11 00:00:39 2018-08-11 00:03:45          car  39.097540
# 18     2018-08-11 00:10:46 2018-08-11 00:11:22          car  39.095212
# 19     2018-08-11 00:17:05 2018-08-11 00:21:41          car  39.097432
# 20     2018-08-11 00:08:57 2018-08-11 00:23:55          car  39.089677
# 21     2018-08-11 00:24:21 2018-08-11 00:26:28          car  39.093783
# 22     2018-08-11 00:27:15 2018-08-11 00:27:40          car  39.093018
# 23     2018-08-11 00:13:12 2018-08-11 00:31:25          car  39.100882
# 24     2018-08-11 00:29:31 2018-08-11 00:32:48          car  39.094201
# 25     2018-08-11 00:33:27 2018-08-11 00:34:15          car  39.109774
# 26     2018-08-11 00:36:50 2018-08-11 00:38:16          car  39.097556
# 27     2018-08-11 00:27:41 2018-08-11 00:41:29          car  39.094159
# 28     2018-08-11 00:38:26 2018-08-11 00:41:32          car  39.094201
# 29     2018-08-11 00:36:29 2018-08-11 00:44:14          car  39.108235
# ...                    ...                 ...          ...        ...
# 162094 2018-11-26 13:34:42 2018-11-26 13:35:30          car  39.094099
# 162095 2018-11-26 13:03:40 2018-11-26 13:41:01          car  39.095145
# 162096 2018-11-26 13:17:53 2018-11-26 13:58:01          car  39.092368
# 162097 2018-11-26 13:55:21 2018-11-26 13:59:01          car  39.092046
# 162098 2018-11-26 13:57:37 2018-11-26 14:04:01          car  39.091947
# 162099 2018-11-26 13:46:10 2018-11-26 14:16:31          car  39.098274
# 162100 2018-11-26 14:13:55 2018-11-26 14:17:31          car  39.092483
# 162101 2018-11-26 14:07:50 2018-11-26 14:18:01          car  39.091396
# 162102 2018-11-26 02:16:55 2018-11-26 14:24:31          car  39.089662
# 162103 2018-11-26 14:24:22 2018-11-26 14:27:31          car  39.094177
# 162104 2018-11-26 14:38:20 2018-11-26 14:39:01          car  39.091441
# 162105 2018-11-26 10:00:18 2018-11-26 14:47:31          car  39.108357
# 162106 2018-11-26 14:27:09 2018-11-26 14:48:01          car  39.089900
# 162107 2018-11-26 14:51:34 2018-11-26 14:58:01          car  39.108356
# 162108 2018-11-26 14:56:48 2018-11-26 15:00:31          car  39.091315
# 162109 2018-11-26 14:54:06 2018-11-26 15:01:01          car  39.092019
# 162110 2018-11-26 14:58:16 2018-11-26 15:01:31          car  39.089948
# 162111 2018-11-26 14:39:51 2018-11-26 15:04:01          car  39.100882
# 162112 2018-11-26 15:02:30 2018-11-26 15:05:31          car  39.089597
# 162113 2018-11-26 15:06:28                 NaT          car  39.089661
# 162114 2018-11-26 15:05:02 2018-11-26 15:11:01          car  39.095211
# 162115 2018-11-26 15:17:34 2018-11-26 15:20:01          car  39.094200
# 162116 2018-11-26 15:19:47 2018-11-26 15:20:31          car  39.094170
# 162117 2018-11-26 15:24:21 2018-11-26 15:25:01          car  39.090085
# 162118 2018-11-26 15:25:32 2018-11-26 15:27:31          car  39.091957
# 162119 2018-11-26 15:30:35 2018-11-26 15:37:31          car  39.090165
# 162120 2018-11-26 15:43:42 2018-11-26 15:45:31          car  39.100888
# 162121 2018-11-26 15:34:46 2018-11-26 15:50:31          car  39.095432
# 162122 2018-11-26 15:50:29                 NaT          car  39.095442
# 162123 2018-11-26 15:48:42 2018-11-26 15:52:31          car  39.091470
#
#         longitude                                           geometry  \
# 0      -94.583482  {"type":"Polygon","coordinates":[[[-94.5834598...
# 1      -94.580771  {"type":"Polygon","coordinates":[[[-94.5807547...
# 2      -94.583396  {"type":"Polygon","coordinates":[[[-94.5834062...
# 3      -94.583515  {"type":"Polygon","coordinates":[[[-94.5835249...
# 4      -94.583621  {"type":"Polygon","coordinates":[[[-94.5836287...
# 5      -94.583381  {"type":"Polygon","coordinates":[[[-94.5833892...
# 6      -94.583603  {"type":"Polygon","coordinates":[[[-94.5836265...
# 7      -94.583630  {"type":"Polygon","coordinates":[[[-94.5836395...
# 8      -94.583495  {"type":"Polygon","coordinates":[[[-94.5835056...
# 9      -94.580507  {"type":"Polygon","coordinates":[[[-94.5805248...
# 10     -94.580498  {"type":"Polygon","coordinates":[[[-94.5805172...
# 11     -94.583481  {"type":"Polygon","coordinates":[[[-94.5834902...
# 12     -94.583651  {"type":"Polygon","coordinates":[[[-94.5836413...
# 13     -94.583405  {"type":"Polygon","coordinates":[[[-94.5834148...
# 14     -94.583507  {"type":"Polygon","coordinates":[[[-94.5834972...
# 15     -94.583506  {"type":"Polygon","coordinates":[[[-94.5835157...
# 16     -94.583488  {"type":"Polygon","coordinates":[[[-94.5834980...
# 17     -94.583369  {"type":"Polygon","coordinates":[[[-94.5833788...
# 18     -94.583512  {"type":"Polygon","coordinates":[[[-94.5835232...
# 19     -94.583384  {"type":"Polygon","coordinates":[[[-94.5833921...
# 20     -94.583627  {"type":"Polygon","coordinates":[[[-94.5836368...
# 21     -94.583424  {"type":"Polygon","coordinates":[[[-94.5834332...
# 22     -94.583617  {"type":"Polygon","coordinates":[[[-94.5836251...
# 23     -94.583494  {"type":"Polygon","coordinates":[[[-94.5835237...
# 24     -94.583402  {"type":"Polygon","coordinates":[[[-94.5833913...
# 25     -94.583495  {"type":"Polygon","coordinates":[[[-94.5834669...
# 26     -94.583371  {"type":"Polygon","coordinates":[[[-94.5833795...
# 27     -94.583399  {"type":"Polygon","coordinates":[[[-94.5833895...
# 28     -94.583403  {"type":"Polygon","coordinates":[[[-94.5833920...
# 29     -94.583061  {"type":"Polygon","coordinates":[[[-94.5830839...
# ...           ...                                                ...
# 162094 -94.583406  {"type":"Polygon","coordinates":[[[-94.5833962...
# 162095 -94.583519  {"type":"Polygon","coordinates":[[[-94.5835295...
# 162096 -94.583648  {"type":"Polygon","coordinates":[[[-94.5836388...
# 162097 -94.583505  {"type":"Polygon","coordinates":[[[-94.5835145...
# 162098 -94.583672  {"type":"Polygon","coordinates":[[[-94.5836813...
# 162099 -94.583330  {"type":"Polygon","coordinates":[[[-94.5833214...
# 162100 -94.583647  {"type":"Polygon","coordinates":[[[-94.5836571...
# 162101 -94.583710  {"type":"Polygon","coordinates":[[[-94.5837189...
# 162102 -94.583787  {"type":"Polygon","coordinates":[[[-94.5837957...
# 162103 -94.583389  {"type":"Polygon","coordinates":[[[-94.5833797...
# 162104 -94.583543  {"type":"Polygon","coordinates":[[[-94.5835530...
# 162105 -94.582504  {"type":"Polygon","coordinates":[[[-94.5825260...
# 162106 -94.583633  {"type":"Polygon","coordinates":[[[-94.5836248...
# 162107 -94.582516  {"type":"Polygon","coordinates":[[[-94.5825383...
# 162108 -94.583539  {"type":"Polygon","coordinates":[[[-94.5835307...
# 162109 -94.583522  {"type":"Polygon","coordinates":[[[-94.5835317...
# 162110 -94.583613  {"type":"Polygon","coordinates":[[[-94.5836032...
# 162111 -94.583414  {"type":"Polygon","coordinates":[[[-94.5834407...
# 162112 -94.583637  {"type":"Polygon","coordinates":[[[-94.5836462...
# 162113 -94.583784  {"type":"Polygon","coordinates":[[[-94.5837937...
# 162114 -94.583517  {"type":"Polygon","coordinates":[[[-94.5835260...
# 162115 -94.583387  {"type":"Polygon","coordinates":[[[-94.5833761...
# 162116 -94.583396  {"type":"Polygon","coordinates":[[[-94.5833848...
# 162117 -94.583625  {"type":"Polygon","coordinates":[[[-94.5836352...
# 162118 -94.583670  {"type":"Polygon","coordinates":[[[-94.5836798...
# 162119 -94.583606  {"type":"Polygon","coordinates":[[[-94.5836163...
# 162120 -94.583408  {"type":"Polygon","coordinates":[[[-94.5834370...
# 162121 -94.583501  {"type":"Polygon","coordinates":[[[-94.5834901...
# 162122 -94.583495  {"type":"Polygon","coordinates":[[[-94.5834863...
# 162123 -94.583535  {"type":"Polygon","coordinates":[[[-94.5835433...
#
#              start_from_fc         end_from_fc
# 0      2018-08-10 23:30:00 2018-08-10 23:35:00
# 1      2018-08-10 23:30:00 2018-08-10 23:40:00
# 2      2018-08-10 23:30:00 2018-08-10 23:40:00
# 3      2018-08-10 23:30:00 2018-08-10 23:40:00
# 4      2018-08-10 23:35:00 2018-08-10 23:40:00
# 5      2018-08-10 23:30:00 2018-08-10 23:40:00
# 6      2018-08-10 23:35:00 2018-08-10 23:45:00
# 7      2018-08-10 23:30:00 2018-08-10 23:50:00
# 8      2018-08-10 23:45:00 2018-08-10 23:50:00
# 9      2018-08-10 23:45:00 2018-08-10 23:50:00
# 10     2018-08-10 23:45:00 2018-08-10 23:55:00
# 11     2018-08-10 23:45:00 2018-08-10 23:55:00
# 12     2018-08-10 23:50:00 2018-08-10 23:55:00
# 13     2018-08-10 23:45:00 2018-08-11 00:00:00
# 14     2018-08-10 23:50:00 2018-08-11 00:00:00
# 15     2018-08-10 23:55:00 2018-08-11 00:00:00
# 16     2018-08-10 23:55:00 2018-08-11 00:05:00
# 17     2018-08-11 00:00:00 2018-08-11 00:05:00
# 18     2018-08-11 00:10:00 2018-08-11 00:15:00
# 19     2018-08-11 00:15:00 2018-08-11 00:25:00
# 20     2018-08-11 00:05:00 2018-08-11 00:25:00
# 21     2018-08-11 00:20:00 2018-08-11 00:30:00
# 22     2018-08-11 00:25:00 2018-08-11 00:30:00
# 23     2018-08-11 00:10:00 2018-08-11 00:35:00
# 24     2018-08-11 00:25:00 2018-08-11 00:35:00
# 25     2018-08-11 00:30:00 2018-08-11 00:35:00
# 26     2018-08-11 00:35:00 2018-08-11 00:40:00
# 27     2018-08-11 00:25:00 2018-08-11 00:45:00
# 28     2018-08-11 00:35:00 2018-08-11 00:45:00
# 29     2018-08-11 00:35:00 2018-08-11 00:45:00
# ...                    ...                 ...
# 162094 2018-11-26 13:30:00 2018-11-26 13:40:00
# 162095 2018-11-26 13:00:00 2018-11-26 13:45:00
# 162096 2018-11-26 13:15:00 2018-11-26 14:00:00
# 162097 2018-11-26 13:55:00 2018-11-26 14:00:00
# 162098 2018-11-26 13:55:00 2018-11-26 14:05:00
# 162099 2018-11-26 13:45:00 2018-11-26 14:20:00
# 162100 2018-11-26 14:10:00 2018-11-26 14:20:00
# 162101 2018-11-26 14:05:00 2018-11-26 14:20:00
# 162102 2018-11-26 02:15:00 2018-11-26 14:25:00
# 162103 2018-11-26 14:20:00 2018-11-26 14:30:00
# 162104 2018-11-26 14:35:00 2018-11-26 14:40:00
# 162105 2018-11-26 10:00:00 2018-11-26 14:50:00
# 162106 2018-11-26 14:25:00 2018-11-26 14:50:00
# 162107 2018-11-26 14:50:00 2018-11-26 15:00:00
# 162108 2018-11-26 14:55:00 2018-11-26 15:05:00
# 162109 2018-11-26 14:50:00 2018-11-26 15:05:00
# 162110 2018-11-26 14:55:00 2018-11-26 15:05:00
# 162111 2018-11-26 14:35:00 2018-11-26 15:05:00
# 162112 2018-11-26 15:00:00 2018-11-26 15:10:00
# 162113 2018-11-26 15:05:00                 NaT
# 162114 2018-11-26 15:05:00 2018-11-26 15:15:00
# 162115 2018-11-26 15:15:00 2018-11-26 15:25:00
# 162116 2018-11-26 15:15:00 2018-11-26 15:25:00
# 162117 2018-11-26 15:20:00 2018-11-26 15:30:00
# 162118 2018-11-26 15:25:00 2018-11-26 15:30:00
# 162119 2018-11-26 15:30:00 2018-11-26 15:40:00
# 162120 2018-11-26 15:40:00 2018-11-26 15:50:00
# 162121 2018-11-26 15:30:00 2018-11-26 15:55:00
# 162122 2018-11-26 15:50:00                 NaT
# 162123 2018-11-26 15:45:00 2018-11-26 15:55:00
#
# [162124 rows x 10 columns]
